# %%
import yfinance as yf
import pandas as pd
import numpy as np

# Set Pandas option to display all rows (optional)
pd.set_option('display.max_rows', None)

# --------------------------
# Stock List Transformation
# --------------------------
# Original list of stocks in the format NSE:{stockname}
stocks = [
    "NSE:IREDA", "NSE:HAL", "NSE:KOTAKBANK", "NSE:POLICYBZR", "NSE:TITAGARH", "NSE:KPITTECH", "NSE:JUBLFOOD",
    "NSE:FEDERALBNK", "NSE:NTPC", "NSE:PFC", "NSE:CANBK", "NSE:OFSS", "NSE:RBLBANK", "NSE:CUMMINSIND",
    "NSE:UNIONBANK", "NSE:KALYANKJIL", "NSE:DIXON", "NSE:CONCOR", "NSE:CHAMBLFERT", "NSE:POONAWALLA",
    "NSE:SBIN", "NSE:RECLTD", "NSE:ICICIGI", "NSE:BANKBARODA", "NSE:GAIL", "NSE:TECHM", "NSE:HINDCOPPER",
    "NSE:IEX", "NSE:HUDCO", "NSE:POWERGRID", "NSE:BOSCHLTD", "NSE:TATAELXSI", "NSE:LODHA", "NSE:PNB",
    "NSE:NMDC", "NSE:IDFCFIRSTB", "NSE:JSWENERGY", "NSE:PERSISTENT", "NSE:IGL", "NSE:NAUKRI", "NSE:ICICIPRULI",
    "NSE:MANAPPURAM", "NSE:HDFCAMC", "NSE:PEL", "NSE:BHEL", "NSE:AXISBANK", "NSE:HFCL", "NSE:BAJAJFINSV",
    "NSE:IRFC", "NSE:HCLTECH", "NSE:PAGEIND", "NSE:BERGEPAINT", "NSE:LTF", "NSE:EICHERMOT", "NSE:LTIM",
    "NSE:SUPREMEIND", "NSE:MPHASIS", "NSE:BEL", "NSE:GODREJPROP", "NSE:TORNTPOWER", "NSE:INDHOTEL",
    "NSE:SOLARINDS", "NSE:EXIDEIND", "NSE:MOTHERSON", "NSE:RELIANCE", "NSE:CESC", "NSE:PATANJALI",
    "NSE:DIVISLAB", "NSE:BAJFINANCE", "NSE:NBCC", "NSE:LT", "NSE:LAURUSLABS", "NSE:WIPRO", "NSE:PAYTM",
    "NSE:TATATECH", "NSE:ASTRAL", "NSE:SJVN", "NSE:GRASIM", "NSE:MRF", "NSE:BHARATFORG", "NSE:BANKINDIA",
    "NSE:SAIL", "NSE:HDFCBANK", "NSE:APOLLOTYRE", "NSE:BANDHANBNK", "NSE:IOC", "NSE:ANGELONE", "NSE:MARUTI",
    "NSE:DEEPAKNTR", "NSE:BSOFT", "NSE:APLAPOLLO", "NSE:CDSL", "NSE:SHREECEM", "NSE:JIOFIN", "NSE:NCC",
    "NSE:MFSL", "NSE:SBILIFE", "NSE:BIOCON", "NSE:YESBANK", "NSE:TORNTPHARM", "NSE:TATAMOTORS", "NSE:ALKEM",
    "NSE:DLF", "NSE:TCS", "NSE:HINDPETRO", "NSE:ABB", "NSE:VOLTAS", "NSE:ESCORTS", "NSE:OBEROIRLTY",
    "NSE:AUBANK", "NSE:ITC", "NSE:TVSMOTOR", "NSE:NHPC", "NSE:LICI", "NSE:LICHSGFIN", "NSE:OIL",
    "NSE:ICICIBANK", "NSE:VEDL", "NSE:COLPAL", "NSE:PIIND", "NSE:ADANIPORTS", "NSE:TATAPOWER",
    "NSE:PETRONET", "NSE:ASIANPAINT", "NSE:TATACONSUM", "NSE:PHOENIXLTD", "NSE:AMBUJACEM", "NSE:ACC",
    "NSE:JINDALSTEL", "NSE:HINDALCO", "NSE:DRREDDY", "NSE:NATIONALUM", "NSE:ASHOKLEY", "NSE:GRANULES",
    "NSE:AUROPHARMA", "NSE:SHRIRAMFIN", "NSE:MGL", "NSE:BAJAJ-AUTO", "NSE:TATASTEEL", "NSE:GMRAIRPORT",
    "NSE:ULTRACEMCO", "NSE:POLYCAB", "NSE:IRCTC", "NSE:TATACHEM", "NSE:IRB", "NSE:RAMCOCEM", "NSE:M&M",
    "NSE:ABFRL", "NSE:ONGC", "NSE:SYNGENE", "NSE:ZYDUSLIFE", "NSE:HINDUNILVR", "NSE:SIEMENS", "NSE:NYKAA",
    "NSE:DMART", "NSE:MARICO", "NSE:CYIENT", "NSE:COFORGE", "NSE:AARTIIND", "NSE:BPCL", "NSE:ADANIENT",
    "NSE:LUPIN", "NSE:JSWSTEEL", "NSE:HAVELLS", "NSE:COALINDIA", "NSE:TATACOMM", "NSE:DABUR",
    "NSE:APOLLOHOSP", "NSE:UNITDSPR", "NSE:INDUSTOWER", "NSE:HDFCLIFE", "NSE:BALKRISIND", "NSE:SUNPHARMA",
    "NSE:INFY", "NSE:CIPLA", "NSE:INDIANB", "NSE:UPL", "NSE:HEROMOTOCO", "NSE:CAMS", "NSE:PIDILITIND",
    "NSE:ADANIGREEN", "NSE:DALBHARAT", "NSE:MUTHOOTFIN", "NSE:CROMPTON", "NSE:NESTLEIND", "NSE:KEI",
    "NSE:SBICARD", "NSE:BRITANNIA", "NSE:BHARTIARTL", "NSE:PRESTIGE", "NSE:ABCAPITAL", "NSE:GODREJCP",
    "NSE:CHOLAFIN", "NSE:TIINDIA", "NSE:IIFL", "NSE:ATGL", "NSE:SRF", "NSE:VBL", "NSE:MCX", "NSE:CGPOWER",
    "NSE:ADANIENSOL", "NSE:DELHIVERY", "NSE:SONACOMS", "NSE:INDIGO", "NSE:GLENMARK", "NSE:JKCEMENT",
    "NSE:TRENT", "NSE:LTTS", "NSE:MAXHEALTH", "NSE:ZOMATO", "NSE:INDUSINDBK", "NSE:BSE", "NSE:TITAN",
    "NSE:IDEA", "NSE:JSL"
]

# Transform into the required format: {STOCKNAME}.NS
transformed_stocks = [stock.split(":")[1].upper() + ".NS" for stock in stocks]

# --------------------------
# Configuration
# --------------------------
FUND_WEIGHT = 0.6
TECH_WEIGHT = 0.4
DISPLAY_FULL_INFO = True  # Set to True to print additional raw info for missing keys

# --------------------------
# Curated Fundamental Attributes (for printing)
# --------------------------
curated_fundamental_keys = [
    'longName', 'sector', 'industry', 'marketCap', 'trailingPE', 'forwardPE',
    'dividendYield', 'dividendRate', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow',
    'returnOnEquity', 'returnOnAssets', 'debtToEquity', 'profitMargins',
    'operatingMargins', 'grossMargins', 'ebitdaMargins', 'bookValue', 'priceToBook',
    'revenueGrowth', 'earningsGrowth', 'trailingPegRatio', 'enterpriseValue',
    'totalDebt', 'totalRevenue', 'revenuePerShare'
]

# --------------------------
# Fundamental Scoring Functions
# --------------------------
def score_pe(pe):
    if pe is None:
        return 5
    if pe < 15:
        return 10
    elif pe < 25:
        return 7
    elif pe < 40:
        return 5
    else:
        return 3

def score_roe(roe):
    if roe is None:
        return 5
    if roe > 0.20:
        return 10
    elif roe > 0.15:
        return 8
    elif roe > 0.10:
        return 6
    else:
        return 4

def score_roa(roa):
    if roa is None:
        return 5
    if roa > 0.10:
        return 10
    elif roa > 0.05:
        return 6
    else:
        return 4

def score_debt(debt):
    if debt is None:
        return 5
    if debt < 0.5:
        return 10
    elif debt < 1:
        return 7
    else:
        return 4

def score_profit_margin(pm):
    if pm is None:
        return 5
    if pm > 0.20:
        return 10
    elif pm > 0.10:
        return 7
    else:
        return 4

def score_operating_margin(om):
    if om is None:
        return 5
    if om > 0.20:
        return 10
    elif om > 0.10:
        return 7
    else:
        return 4

def score_price_to_book(pb):
    if pb is None:
        return 5
    if pb < 3:
        return 10
    elif pb < 5:
        return 7
    else:
        return 4

def score_price_to_sales(ps):
    if ps is None:
        return 5
    if ps < 2:
        return 10
    elif ps < 4:
        return 7
    else:
        return 4

def score_beta(beta):
    if beta is None:
        return 5
    if beta < 1:
        return 10
    elif beta < 1.5:
        return 7
    else:
        return 4

def score_peg(peg):
    if peg is None:
        return 5
    if peg < 1:
        return 10
    elif peg < 1.5:
        return 8
    elif peg < 2:
        return 6
    else:
        return 4

def score_ev_ebitda(ev, ebitda):
    if ev is None or ebitda is None or ebitda <= 0:
        return 5
    ratio = ev / ebitda
    if ratio < 10:
        return 10
    elif ratio < 15:
        return 8
    elif ratio < 20:
        return 6
    else:
        return 4

def score_revenue_growth(rg):
    if rg is None:
        return 5
    if rg > 0.15:
        return 10
    elif rg > 0.10:
        return 8
    elif rg > 0:
        return 6
    else:
        return 4

# Define weights for each fundamental metric
fundamental_metric_weights = {
    'trailingPE': (score_pe, 1.0),
    'returnOnEquity': (score_roe, 2.0),
    'returnOnAssets': (score_roa, 1.5),
    'debtToEquity': (score_debt, 1.0),
    'profitMargins': (score_profit_margin, 1.0),
    'operatingMargins': (score_operating_margin, 1.0),
    'priceToBook': (score_price_to_book, 1.0),
    'priceToSalesTrailing12Months': (score_price_to_sales, 1.0),
    'beta': (score_beta, 1.0),
    'pegRatio': (score_peg, 1.0),
    'enterpriseValue_ebitda': (score_ev_ebitda, 1.0),
    'revenueGrowth': (score_revenue_growth, 1.0)
}

def compute_weighted_fundamental_score(info):
    total_weight = 0
    weighted_sum = 0
    # First, process the EV/EBITDA metric if available
    if info.get('enterpriseValue') is not None and info.get('ebitda') is not None:
        score_val = score_ev_ebitda(info['enterpriseValue'], info['ebitda'])
        weight = fundamental_metric_weights['enterpriseValue_ebitda'][1]
        weighted_sum += score_val * weight
        total_weight += weight
    # Process the remaining metrics
    for key, (score_func, weight) in fundamental_metric_weights.items():
        if key == 'enterpriseValue_ebitda':
            continue
        value = info.get(key)
        if value is not None:
            weighted_sum += score_func(value) * weight
            total_weight += weight
    if total_weight == 0:
        return 5
    return weighted_sum / total_weight

# --------------------------
# Technical Indicator Functions
# --------------------------
def compute_RSI(series, period=14):
    delta = series.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=period, min_periods=period).mean()
    avg_loss = loss.rolling(window=period, min_periods=period).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def compute_MACD(series, fast=12, slow=26, signal=9):
    ema_fast = series.ewm(span=fast, adjust=False).mean()
    ema_slow = series.ewm(span=slow, adjust=False).mean()
    macd = ema_fast - ema_slow
    macd_signal = macd.ewm(span=signal, adjust=False).mean()
    macd_hist = macd - macd_signal
    return macd, macd_signal, macd_hist

def compute_bollinger_bands(series, window=20, num_std=2):
    ma = series.rolling(window=window).mean()
    std = series.rolling(window=window).std()
    upper = ma + num_std * std
    lower = ma - num_std * std
    return lower, ma, upper

def compute_ATR(high, low, close, period=14):
    tr1 = high - low
    tr2 = (high - close.shift(1)).abs()
    tr3 = (low - close.shift(1)).abs()
    true_range = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    atr = true_range.rolling(window=period).mean()
    return atr

def compute_volume_MA(volume, period=20):
    return volume.rolling(window=period).mean()

def compute_stochastic(high, low, close, period=14, smooth_d=3):
    lowest_low = low.rolling(window=period).min()
    highest_high = high.rolling(window=period).max()
    k = 100 * (close - lowest_low) / (highest_high - lowest_low)
    d = k.rolling(window=smooth_d).mean()
    return k, d

def score_bollinger(last_close, lower, middle, upper):
    if lower is None or middle is None or upper is None:
        return 5
    threshold = 0.1 * middle  # within 10% of the middle is optimal
    distance = abs(last_close - middle)
    if distance <= threshold:
        return 10
    elif last_close < lower or last_close > upper:
        return 4
    else:
        return 7

def score_technicals(last_close, ma50, ma200, rsi, macd, macd_signal, bb_score):
    tech_scores = []
    # Price relative to MAs
    if last_close > ma50 and last_close > ma200:
        tech_scores.append(10)
    elif last_close < ma50 and last_close < ma200:
        tech_scores.append(4)
    else:
        tech_scores.append(7)
    # MA Crossover
    tech_scores.append(10 if ma50 > ma200 else 4)
    # RSI scoring: 40-60 is optimal
    if 40 <= rsi <= 60:
        tech_scores.append(10)
    elif rsi < 30 or rsi > 70:
        tech_scores.append(4)
    else:
        tech_scores.append(7)
    # MACD vs. Signal
    tech_scores.append(10 if macd > macd_signal else 4)
    # Bollinger Bands score
    tech_scores.append(bb_score)
    return np.mean(tech_scores)

# --------------------------
# Functions to Compute Missing Fundamental Metrics
# --------------------------
def compute_ROE(stock):
    """
    Compute ROE = (Net Income - Preferred Dividends) / Total Equity.
    Tries annual data first; if not available, falls back to quarterly data.
    """
    try:
        fin = stock.financials
        bs = stock.balance_sheet
        if fin.empty:
            fin = stock.quarterly_financials
        if bs.empty:
            bs = stock.quarterly_balance_sheet
        if fin.empty or bs.empty:
            return None
        net_income_keys = ['Net Income', 'Net Income Common Stock']
        net_income = None
        for key in net_income_keys:
            if key in fin.index:
                net_income = fin.loc[key].iloc[0]
                break
        if net_income is None:
            return None
        pref_div = fin.loc['Preferred Dividends'].iloc[0] if 'Preferred Dividends' in fin.index else 0
        equity_keys = ['Total Stockholder Equity', 'Total Equity', "Total Shareholders' Equity"]
        equity = None
        for key in equity_keys:
            if key in bs.index:
                equity = bs.loc[key].iloc[0]
                break
        if equity is None or equity == 0:
            return None
        return (net_income - pref_div) / equity
    except Exception:
        return None

def compute_ROA(stock):
    """
    Compute ROA = Net Income / Total Assets.
    Tries annual data first; if not available, falls back to quarterly data.
    """
    try:
        fin = stock.financials
        bs = stock.balance_sheet
        if fin.empty:
            fin = stock.quarterly_financials
        if bs.empty:
            bs = stock.quarterly_balance_sheet
        if fin.empty or bs.empty:
            return None
        net_income_keys = ['Net Income', 'Net Income Common Stock']
        net_income = None
        for key in net_income_keys:
            if key in fin.index:
                net_income = fin.loc[key].iloc[0]
                break
        if net_income is None:
            return None
        total_assets_keys = ['Total Assets']
        total_assets = None
        for key in total_assets_keys:
            if key in bs.index:
                total_assets = bs.loc[key].iloc[0]
                break
        if total_assets is None or total_assets == 0:
            return None
        return net_income / total_assets
    except Exception:
        return None

def compute_peg_ratio(info):
    """
    Compute PEG Ratio manually as: trailingPE / (earningsGrowth * 100).
    (Assumes earningsGrowth is provided as a decimal.)
    """
    try:
        pe = info.get('trailingPE')
        eg = info.get('earningsGrowth')
        if pe is not None and eg is not None and eg > 0:
            return pe / (eg * 100)
    except Exception:
        return None
    return None

# --------------------------
# Main Analysis and Excel Output
# --------------------------
results = []  # To store {"Stock Name": ..., "Composite Score": ...}

# Loop through each stock in our transformed list
nifty_top_10 = transformed_stocks

for symbol in nifty_top_10:
    try:
        stock = yf.Ticker(symbol)
        info = stock.info

        # Compute missing fundamental metrics
        computed_roe = compute_ROE(stock)
        computed_roa = compute_ROA(stock)
        if computed_roe is not None:
            info['returnOnEquity'] = computed_roe
        if computed_roa is not None:
            info['returnOnAssets'] = computed_roa

        if info.get('pegRatio') is None:
            computed_peg = compute_peg_ratio(info)
            if computed_peg is not None:
                info['pegRatio'] = computed_peg

        # --------------------------
        # Display Curated Fundamental Metrics (Optional Printing)
        # --------------------------
        print(f"=== {info.get('longName', symbol)} ({symbol}) ===")
        print("Fundamental Metrics:")
        for key in curated_fundamental_keys:
            print(f"{key}: {info.get(key, 'N/A')}")
        print()
        if info.get('returnOnEquity') is not None:
            print(f"Computed ROE: {info.get('returnOnEquity'):.2%}")
        else:
            print("Computed ROE: N/A")
        if info.get('returnOnAssets') is not None:
            print(f"Computed ROA: {info.get('returnOnAssets'):.2%}")
        else:
            print("Computed ROA: N/A")
        
        fundamental_score = compute_weighted_fundamental_score(info)
        print(f"Fundamental Score: {fundamental_score:.2f}/10\n")
        
        # If key fundamentals are missing, print additional info (optional)
        missing_keys = []
        for key in ['returnOnEquity', 'pegRatio']:
            if info.get(key) is None:
                missing_keys.append(key)
        if DISPLAY_FULL_INFO and missing_keys:
            df_info = pd.DataFrame.from_dict(info, orient='index').reset_index()
            df_info.columns = ['Attribute', 'Value']
            print("Additional info for missing metrics:")
            print(df_info[df_info['Attribute'].isin(missing_keys)])
            print("\n")
        
        # --------------------------
        # Technical Analysis (using 1-year history)
        # --------------------------
        hist = stock.history(period="1y")
        if not hist.empty:
            hist['MA50'] = hist['Close'].rolling(window=50).mean()
            hist['MA200'] = hist['Close'].rolling(window=200).mean()
            hist['RSI'] = compute_RSI(hist['Close'], period=14)
            macd_series, macd_signal_series, _ = compute_MACD(hist['Close'])
            hist['MACD'] = macd_series
            hist['MACD_Signal'] = macd_signal_series
            lower_bb, middle_bb, upper_bb = compute_bollinger_bands(hist['Close'])
            
            # Additional technical indicators
            hist['ATR14'] = compute_ATR(hist['High'], hist['Low'], hist['Close'], period=14)
            hist['VolMA20'] = compute_volume_MA(hist['Volume'], period=20)
            stoch_k, stoch_d = compute_stochastic(hist['High'], hist['Low'], hist['Close'], period=14, smooth_d=3)
            hist['StochK'] = stoch_k
            hist['StochD'] = stoch_d
            
            last_close = hist['Close'].iloc[-1]
            ma50 = hist['MA50'].iloc[-1]
            ma200 = hist['MA200'].iloc[-1]
            rsi = hist['RSI'].iloc[-1]
            macd = hist['MACD'].iloc[-1]
            macd_signal = hist['MACD_Signal'].iloc[-1]
            bb_score = score_bollinger(last_close, lower_bb.iloc[-1], middle_bb.iloc[-1], upper_bb.iloc[-1])
            atr = hist['ATR14'].iloc[-1]
            vol_ma20 = hist['VolMA20'].iloc[-1]
            stoch_k_val = hist['StochK'].iloc[-1]
            stoch_d_val = hist['StochD'].iloc[-1]
            
            print(f"Technical Metrics as of {hist.index[-1].date()}:")
            print(f"Close Price: {last_close:.2f}")
            print(f"50-Day MA: {ma50:.2f}")
            print(f"200-Day MA: {ma200:.2f}")
            print(f"RSI (14): {rsi:.2f}")
            print(f"MACD: {macd:.2f}")
            print(f"MACD Signal: {macd_signal:.2f}")
            print(f"Bollinger Bands Score: {bb_score:.2f}")
            print(f"ATR (14): {atr:.2f}")
            print(f"Volume MA (20): {vol_ma20:.2f}")
            print(f"Stochastic %K: {stoch_k_val:.2f}")
            print(f"Stochastic %D: {stoch_d_val:.2f}")
            print()
            
            technical_score = score_technicals(last_close, ma50, ma200, rsi, macd, macd_signal, bb_score)
            print(f"Technical Score: {technical_score:.2f}/10\n")
            
            # Composite Score (weighted average of fundamental and technical scores)
            composite_score = FUND_WEIGHT * fundamental_score + TECH_WEIGHT * technical_score
            composite_score = max(1, min(10, composite_score))
            print(f"Composite Financial Strength Score: {composite_score:.2f}/10")
            print("="*60 + "\n")
            
            # Save result for Excel output (using the longName if available)
            stock_name = info.get('longName', symbol)
            results.append({"Stock Name": stock_name, "Composite Score": composite_score})
        else:
            print("No historical data available for technical analysis.\n")
            
    except Exception as e:
        print(f"Error processing {symbol}: {e}\n")

# --------------------------
# Save Results to Excel
# --------------------------
df_results = pd.DataFrame(results)
output_file = "composite_scores.xlsx"
df_results.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# === Indian Renewable Energy Development Agency Limited (IREDA.NS) ===
# Fundamental Metrics:
# longName: Indian Renewable Energy Development Agency Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 456812003328
# trailingPE: 29.81579
# forwardPE: 25.946564
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 310.0
# fiftyTwoWeekLow: 135.0
# returnOnEquity: N/A
# returnOnAssets: 0.020003524225606983
# debtToEquity: 586.184
# profitMargins: 0.6898
# operatingMargins: 0.96069
# grossMargins: 1.0
# ebitdaMargins: 0.0
# bookValue: 34.672
# priceToBook: 4.9016495
# revenueGrowth: 0.212
# earningsGrowth: 0.145
# trailingPegRatio: None
# enterpriseValue: 987141505024
# totalDebt: 547270000640
# totalRevenue: 22241163264
# revenuePerShare: 8.271
#
# Computed ROE: N/A
# Computed ROA: 2.00%
# Fundamental Score: 6.32/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 169.95
# 50-Day MA: 174.15
# 200-Day MA: 209.80
# RSI (14): 74.01
# MACD: -4.27
# MACD Signal: -8.57
# Bollinger Bands Score: 7.00
# ATR (14): 6.85
# Volume MA (20): 19417194.05
# Stochastic %K: 82.85
# Stochastic %D: 85.43
#
# Technical Score: 5.80/10
#
# Composite Financial Strength Score: 6.11/10
# ============================================================
#
# === Hindustan Aeronautics Limited (HAL.NS) ===
# Fundamental Metrics:
# longName: Hindustan Aeronautics Limited
# sector: Industrials
# industry: Aerospace & Defense
# marketCap: 2683458289664
# trailingPE: 30.843647
# forwardPE: 31.33992
# dividendYield: 0.92
# dividendRate: 38.0
# fiftyTwoWeekHigh: 5674.75
# fiftyTwoWeekLow: 3046.05
# returnOnEquity: N/A
# returnOnAssets: 0.09758668844863409
# debtToEquity: 0.004
# profitMargins: 0.27133
# operatingMargins: 0.15415
# grossMargins: 0.59347
# ebitdaMargins: 0.2736
# bookValue: 466.598
# priceToBook: 8.599373
# revenueGrowth: 0.148
# earningsGrowth: 0.142
# trailingPegRatio: None
# enterpriseValue: 2472790458368
# totalDebt: 11500000
# totalRevenue: 320498499584
# revenuePerShare: 479.196
#
# Computed ROE: N/A
# Computed ROA: 9.76%
# Fundamental Score: 6.52/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4012.45
# 50-Day MA: 3622.18
# 200-Day MA: 4348.65
# RSI (14): 80.62
# MACD: 98.54
# MACD Signal: 4.98
# Bollinger Bands Score: 7.00
# ATR (14): 141.99
# Volume MA (20): 2007859.60
# Stochastic %K: 77.96
# Stochastic %D: 89.68
#
# Technical Score: 6.40/10
#
# Composite Financial Strength Score: 6.47/10
# ============================================================
#
# === Kotak Mahindra Bank Limited (KOTAKBANK.NS) ===
# Fundamental Metrics:
# longName: Kotak Mahindra Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 4314328989696
# trailingPE: 19.400984
# forwardPE: 19.83728
# dividendYield: 0.09
# dividendRate: 2.0
# fiftyTwoWeekHigh: 2202.5
# fiftyTwoWeekLow: 1543.85
# returnOnEquity: N/A
# returnOnAssets: 0.02372540238507256
# debtToEquity: N/A
# profitMargins: 0.30782
# operatingMargins: 0.39311
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 740.965
# priceToBook: 2.9286132
# revenueGrowth: -0.098
# earningsGrowth: 0.102
# trailingPegRatio: None
# enterpriseValue: 4637164830720
# totalDebt: 770709520384
# totalRevenue: 731945697280
# revenuePerShare: 368.157
#
# Computed ROE: N/A
# Computed ROA: 2.37%
# Fundamental Score: 7.05/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 2170.00
# 50-Day MA: 1936.74
# 200-Day MA: 1827.02
# RSI (14): 90.39
# MACD: 52.32
# MACD Signal: 30.92
# Bollinger Bands Score: 10.00
# ATR (14): 42.05
# Volume MA (20): 4872027.00
# Stochastic %K: 89.42
# Stochastic %D: 92.47
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 7.75/10
# ============================================================
#
# === PB Fintech Limited (POLICYBZR.NS) ===
# Fundamental Metrics:
# longName: PB Fintech Limited
# sector: Financial Services
# industry: Insurance Brokers
# marketCap: 737261387776
# trailingPE: 309.58655
# forwardPE: 96.49955
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 2246.9
# fiftyTwoWeekLow: 1101.05
# returnOnEquity: N/A
# returnOnAssets: 0.009954655636983523
# debtToEquity: 5.473
# profitMargins: 0.0533
# operatingMargins: -0.00456
# grossMargins: 0.5838
# ebitdaMargins: -0.01632
# bookValue: 134.994
# priceToBook: 11.925344
# revenueGrowth: 0.483
# earningsGrowth: 0.867
# trailingPegRatio: None
# enterpriseValue: 733491101696
# totalDebt: 3345600000
# totalRevenue: 45589098496
# revenuePerShare: 102.637
#
# Computed ROE: N/A
# Computed ROA: 1.00%
# Fundamental Score: 5.04/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1609.85
# 50-Day MA: 1584.07
# 200-Day MA: 1670.22
# RSI (14): 65.37
# MACD: -2.91
# MACD Signal: -41.05
# Bollinger Bands Score: 10.00
# ATR (14): 78.01
# Volume MA (20): 2441776.25
# Stochastic %K: 77.20
# Stochastic %D: 90.03
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.07/10
# ============================================================
#
# === Titagarh Rail Systems Limited (TITAGARH.NS) ===
# Fundamental Metrics:
# longName: Titagarh Rail Systems Limited
# sector: Industrials
# industry: Railroads
# marketCap: 109429121024
# trailingPE: 37.494232
# forwardPE: 25.507025
# dividendYield: 0.1
# dividendRate: 0.8
# fiftyTwoWeekHigh: 1896.95
# fiftyTwoWeekLow: 654.55
# returnOnEquity: N/A
# returnOnAssets: 0.08896298387653646
# debtToEquity: 21.138
# profitMargins: 0.07393
# operatingMargins: 0.103879996
# grossMargins: 0.23482999
# ebitdaMargins: 0.11261
# bookValue: 174.775
# priceToBook: 4.648834
# revenueGrowth: -0.055
# earningsGrowth: -0.199
# trailingPegRatio: None
# enterpriseValue: 109842276352
# totalDebt: 4976600064
# totalRevenue: 39145902080
# revenuePerShare: 290.636
#
# Computed ROE: N/A
# Computed ROA: 8.90%
# Fundamental Score: 5.52/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 812.50
# 50-Day MA: 845.70
# 200-Day MA: 1218.00
# RSI (14): 70.43
# MACD: -16.84
# MACD Signal: -38.86
# Bollinger Bands Score: 7.00
# ATR (14): 38.10
# Volume MA (20): 2380549.90
# Stochastic %K: 84.69
# Stochastic %D: 88.87
#
# Technical Score: 5.80/10
#
# Composite Financial Strength Score: 5.63/10
# ============================================================
#
# === KPIT Technologies Limited (KPITTECH.NS) ===
# Fundamental Metrics:
# longName: KPIT Technologies Limited
# sector: Technology
# industry: Software - Infrastructure
# marketCap: 364723437568
# trailingPE: 48.251884
# forwardPE: 39.271843
# dividendYield: 0.51
# dividendRate: 7.1
# fiftyTwoWeekHigh: 1928.7
# fiftyTwoWeekLow: 1142.3
# returnOnEquity: N/A
# returnOnAssets: 0.14264583377320356
# debtToEquity: 13.968
# profitMargins: 0.13481
# operatingMargins: 0.17171
# grossMargins: 0.3461
# ebitdaMargins: 0.18604
# bookValue: 92.163
# priceToBook: 14.57038
# revenueGrowth: 0.175
# earningsGrowth: 0.2
# trailingPegRatio: None
# enterpriseValue: 369328357376
# totalDebt: 3492450048
# totalRevenue: 56318009344
# revenuePerShare: 207.518
#
# Computed ROE: N/A
# Computed ROA: 14.26%
# Fundamental Score: 6.26/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1342.85
# 50-Day MA: 1322.00
# 200-Day MA: 1539.92
# RSI (14): 63.30
# MACD: -1.92
# MACD Signal: -18.18
# Bollinger Bands Score: 10.00
# ATR (14): 52.68
# Volume MA (20): 916242.75
# Stochastic %K: 66.75
# Stochastic %D: 85.41
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.80/10
# ============================================================
#
# === Jubilant FoodWorks Limited (JUBLFOOD.NS) ===
# Fundamental Metrics:
# longName: Jubilant FoodWorks Limited
# sector: Consumer Cyclical
# industry: Restaurants
# marketCap: 439386406912
# trailingPE: 115.414505
# forwardPE: 22.932396
# dividendYield: 0.18
# dividendRate: 1.2
# fiftyTwoWeekHigh: 796.75
# fiftyTwoWeekLow: 429.6
# returnOnEquity: N/A
# returnOnAssets: 0.04914580876621307
# debtToEquity: 187.405
# profitMargins: 0.048649997
# operatingMargins: 0.090299994
# grossMargins: 0.53729
# ebitdaMargins: 0.13834
# bookValue: 33.229
# priceToBook: 20.110445
# revenueGrowth: 0.561
# earningsGrowth: -0.356
# trailingPegRatio: None
# enterpriseValue: 480172605440
# totalDebt: 42419441664
# totalRevenue: 76113403904
# revenuePerShare: 114.902
#
# Computed ROE: N/A
# Computed ROA: 4.91%
# Fundamental Score: 5.05/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 668.25
# 50-Day MA: 665.44
# 200-Day MA: 639.18
# RSI (14): 69.21
# MACD: -7.29
# MACD Signal: -14.91
# Bollinger Bands Score: 10.00
# ATR (14): 21.92
# Volume MA (20): 2247070.80
# Stochastic %K: 91.64
# Stochastic %D: 85.30
#
# Technical Score: 9.40/10
#
# Composite Financial Strength Score: 6.79/10
# ============================================================
#
# === The Federal Bank Limited (FEDERALBNK.NS) ===
# Fundamental Metrics:
# longName: The Federal Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 478290542592
# trailingPE: 11.932028
# forwardPE: 16.668093
# dividendYield: 0.61
# dividendRate: 1.2
# fiftyTwoWeekHigh: 217.0
# fiftyTwoWeekLow: 148.0
# returnOnEquity: N/A
# returnOnAssets: 0.012208770645418685
# debtToEquity: N/A
# profitMargins: 0.3052
# operatingMargins: 0.39423
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 132.926
# priceToBook: 1.4658533
# revenueGrowth: 0.038
# earningsGrowth: -0.097
# trailingPegRatio: None
# enterpriseValue: 579002105856
# totalDebt: 323250290688
# totalRevenue: 132330848256
# revenuePerShare: 54.132
#
# Computed ROE: N/A
# Computed ROA: 1.22%
# Fundamental Score: 8.12/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 194.85
# 50-Day MA: 184.46
# 200-Day MA: 192.02
# RSI (14): 80.05
# MACD: 1.74
# MACD Signal: -0.45
# Bollinger Bands Score: 10.00
# ATR (14): 4.00
# Volume MA (20): 7041218.00
# Stochastic %K: 88.76
# Stochastic %D: 92.64
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 7.91/10
# ============================================================
#
# === NTPC Limited (NTPC.NS) ===
# Fundamental Metrics:
# longName: NTPC Limited
# sector: Utilities
# industry: Utilities - Regulated Electric
# marketCap: 3562071916544
# trailingPE: 17.123192
# forwardPE: 15.232462
# dividendYield: 3.13
# dividendRate: 11.5
# fiftyTwoWeekHigh: 448.45
# fiftyTwoWeekLow: 292.8
# returnOnEquity: N/A
# returnOnAssets: 0.04334035538821113
# debtToEquity: 139.959
# profitMargins: 0.118240006
# operatingMargins: 0.20751
# grossMargins: 0.42384997
# ebitdaMargins: 0.28405002
# bookValue: 173.535
# priceToBook: 2.114559
# revenueGrowth: 0.052
# earningsGrowth: 0.047
# trailingPegRatio: None
# enterpriseValue: 5945994248192
# totalDebt: 2420094795776
# totalRevenue: 1858917498880
# revenuePerShare: 190.712
#
# Computed ROE: N/A
# Computed ROA: 4.33%
# Fundamental Score: 7.13/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 366.95
# 50-Day MA: 322.75
# 200-Day MA: 366.30
# RSI (14): 87.46
# MACD: 10.14
# MACD Signal: 5.96
# Bollinger Bands Score: 4.00
# ATR (14): 9.21
# Volume MA (20): 14059623.75
# Stochastic %K: 92.23
# Stochastic %D: 94.99
#
# Technical Score: 6.40/10
#
# Composite Financial Strength Score: 6.84/10
# ============================================================
#
# === Power Finance Corporation Limited (PFC.NS) ===
# Fundamental Metrics:
# longName: Power Finance Corporation Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 1383566934016
# trailingPE: 6.2046766
# forwardPE: 7.624113
# dividendYield: 3.29
# dividendRate: 14.0
# fiftyTwoWeekHigh: 580.0
# fiftyTwoWeekLow: 357.25
# returnOnEquity: N/A
# returnOnAssets: 0.01902164815639744
# debtToEquity: 635.304
# profitMargins: 0.53849
# operatingMargins: 0.95707
# grossMargins: 0.99573
# ebitdaMargins: 0.0
# bookValue: 333.463
# priceToBook: 1.2572609
# revenueGrowth: 0.216
# earningsGrowth: 0.232
# trailingPegRatio: None
# enterpriseValue: 10681413795840
# totalDebt: 9221964824576
# totalRevenue: 414099013632
# revenuePerShare: 125.481
#
# Computed ROE: N/A
# Computed ROA: 1.90%
# Fundamental Score: 8.29/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 419.25
# 50-Day MA: 393.69
# 200-Day MA: 458.07
# RSI (14): 69.76
# MACD: 6.15
# MACD Signal: 1.59
# Bollinger Bands Score: 10.00
# ATR (14): 13.25
# Volume MA (20): 8424953.15
# Stochastic %K: 75.17
# Stochastic %D: 88.05
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 8.01/10
# ============================================================
#
# === Canara Bank (CANBK.NS) ===
# Fundamental Metrics:
# longName: Canara Bank
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 802389753856
# trailingPE: 4.884594
# forwardPE: 4.6730056
# dividendYield: 3.53
# dividendRate: 3.22
# fiftyTwoWeekHigh: 128.9
# fiftyTwoWeekLow: 78.6
# returnOnEquity: 0.16985
# returnOnAssets: 0.00995334778814054
# debtToEquity: N/A
# profitMargins: 0.2736
# operatingMargins: 0.39765
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 114.473
# priceToBook: 0.77275866
# revenueGrowth: -0.082
# earningsGrowth: 0.113
# trailingPegRatio: None
# enterpriseValue: 1175698800640
# totalDebt: 924928114688
# totalRevenue: 600184389632
# revenuePerShare: 66.17
#
# Computed ROE: 16.98%
# Computed ROA: 1.00%
# Fundamental Score: 8.35/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 88.46
# 50-Day MA: 89.32
# 200-Day MA: 102.98
# RSI (14): 65.96
# MACD: -0.32
# MACD Signal: -1.45
# Bollinger Bands Score: 10.00
# ATR (14): 2.34
# Volume MA (20): 20427596.15
# Stochastic %K: 65.07
# Stochastic %D: 85.12
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.81/10
# ============================================================
#
# === Oracle Financial Services Software Limited (OFSS.NS) ===
# Fundamental Metrics:
# longName: Oracle Financial Services Software Limited
# sector: Technology
# industry: Software - Infrastructure
# marketCap: 691773440000
# trailingPE: 30.313452
# forwardPE: 30.51322
# dividendYield: 3.01
# dividendRate: 240.0
# fiftyTwoWeekHigh: 13220.0
# fiftyTwoWeekLow: 7022.55
# returnOnEquity: 0.30737
# returnOnAssets: 0.2233715633287945
# debtToEquity: 0.318
# profitMargins: 0.33897
# operatingMargins: 0.40637
# grossMargins: 0.53208
# ebitdaMargins: 0.44559
# bookValue: 882.651
# priceToBook: 9.022762
# revenueGrowth: -0.059
# earningsGrowth: -0.272
# trailingPegRatio: None
# enterpriseValue: 637793402880
# totalDebt: 244000000
# totalRevenue: 67729608704
# revenuePerShare: 781.05
#
# Computed ROE: 30.74%
# Computed ROA: 22.34%
# Fundamental Score: 7.68/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 7963.95
# 50-Day MA: 8713.74
# 200-Day MA: 10559.04
# RSI (14): 58.00
# MACD: -314.77
# MACD Signal: -440.09
# Bollinger Bands Score: 10.00
# ATR (14): 285.78
# Volume MA (20): 182971.15
# Stochastic %K: 81.65
# Stochastic %D: 74.39
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 7.65/10
# ============================================================
#
# === RBL Bank Limited (RBLBANK.NS) ===
# Fundamental Metrics:
# longName: RBL Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 106493796352
# trailingPE: 10.827565
# forwardPE: 8.993327
# dividendYield: 0.86
# dividendRate: 1.5
# fiftyTwoWeekHigh: 272.05
# fiftyTwoWeekLow: 146.1
# returnOnEquity: N/A
# returnOnAssets: 0.00909971565073719
# debtToEquity: N/A
# profitMargins: 0.13143
# operatingMargins: -0.12069
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 255.482
# priceToBook: 0.6857235
# revenueGrowth: -0.212
# earningsGrowth: -0.805
# trailingPegRatio: None
# enterpriseValue: 126698962944
# totalDebt: 146797101056
# totalRevenue: 75665711104
# revenuePerShare: 124.777
#
# Computed ROE: N/A
# Computed ROA: 0.91%
# Fundamental Score: 6.82/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 175.19
# 50-Day MA: 160.61
# 200-Day MA: 192.65
# RSI (14): 72.37
# MACD: 2.57
# MACD Signal: 0.55
# Bollinger Bands Score: 10.00
# ATR (14): 5.82
# Volume MA (20): 7014559.75
# Stochastic %K: 89.97
# Stochastic %D: 91.38
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.89/10
# ============================================================
#
# === Cummins India Limited (CUMMINSIND.NS) ===
# Fundamental Metrics:
# longName: Cummins India Limited
# sector: Industrials
# industry: Specialty Industrial Machinery
# marketCap: 821205008384
# trailingPE: 40.90156
# forwardPE: 36.090637
# dividendYield: 1.18
# dividendRate: 36.0
# fiftyTwoWeekHigh: 4171.9
# fiftyTwoWeekLow: 2636.75
# returnOnEquity: N/A
# returnOnAssets: 0.19180403343845556
# debtToEquity: 0.403
# profitMargins: 0.19623
# operatingMargins: 0.21305999
# grossMargins: 0.35691002
# ebitdaMargins: 0.22593
# bookValue: 251.318
# priceToBook: 11.787855
# revenueGrowth: 0.218
# earningsGrowth: 0.119
# trailingPegRatio: None
# enterpriseValue: 819304988672
# totalDebt: 281000000
# totalRevenue: 102393298944
# revenuePerShare: 369.408
#
# Computed ROE: N/A
# Computed ROA: 19.18%
# Fundamental Score: 7.04/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 2962.50
# 50-Day MA: 2848.98
# 200-Day MA: 3422.87
# RSI (14): 56.78
# MACD: 33.79
# MACD Signal: 15.40
# Bollinger Bands Score: 10.00
# ATR (14): 97.99
# Volume MA (20): 463100.60
# Stochastic %K: 59.70
# Stochastic %D: 73.73
#
# Technical Score: 8.20/10
#
# Composite Financial Strength Score: 7.51/10
# ============================================================
#
# === Union Bank of India (UNIONBANK.NS) ===
# Fundamental Metrics:
# longName: Union Bank of India
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 941682196480
# trailingPE: 5.7510486
# forwardPE: 7.0652924
# dividendYield: 2.82
# dividendRate: 3.6
# fiftyTwoWeekHigh: 172.5
# fiftyTwoWeekLow: 100.81
# returnOnEquity: 0.15843001
# returnOnAssets: 0.009841054879498936
# debtToEquity: N/A
# profitMargins: 0.32317
# operatingMargins: 0.47632998
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 147.009
# priceToBook: 0.8391323
# revenueGrowth: 0.049
# earningsGrowth: 0.239
# trailingPegRatio: None
# enterpriseValue: 825767952384
# totalDebt: 327184908288
# totalRevenue: 505737347072
# revenuePerShare: 66.497
#
# Computed ROE: 15.84%
# Computed ROA: 0.98%
# Fundamental Score: 8.26/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 123.36
# 50-Day MA: 113.61
# 200-Day MA: 121.46
# RSI (14): 66.76
# MACD: 2.32
# MACD Signal: 1.16
# Bollinger Bands Score: 10.00
# ATR (14): 3.62
# Volume MA (20): 8683801.90
# Stochastic %K: 68.15
# Stochastic %D: 87.53
#
# Technical Score: 8.20/10
#
# Composite Financial Strength Score: 8.24/10
# ============================================================
#
# === Kalyan Jewellers India Limited (KALYANKJIL.NS) ===
# Fundamental Metrics:
# longName: Kalyan Jewellers India Limited
# sector: Consumer Cyclical
# industry: Luxury Goods
# marketCap: 483951673344
# trailingPE: 72.519325
# forwardPE: 42.994987
# dividendYield: 0.24
# dividendRate: 1.2
# fiftyTwoWeekHigh: 795.4
# fiftyTwoWeekLow: 336.05
# returnOnEquity: N/A
# returnOnAssets: 0.046603085490533235
# debtToEquity: 104.385
# profitMargins: 0.028380001
# operatingMargins: 0.048010003
# grossMargins: 0.13094
# ebitdaMargins: 0.05416
# bookValue: 42.388
# priceToBook: 11.069171
# revenueGrowth: 0.395
# earningsGrowth: 0.211
# trailingPegRatio: None
# enterpriseValue: 540644868096
# totalDebt: 45499129856
# totalRevenue: 234227744768
# revenuePerShare: 227.25
#
# Computed ROE: N/A
# Computed ROA: 4.66%
# Fundamental Score: 5.22/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 469.20
# 50-Day MA: 483.59
# 200-Day MA: 597.06
# RSI (14): 52.72
# MACD: -9.79
# MACD Signal: -18.60
# Bollinger Bands Score: 10.00
# ATR (14): 23.40
# Volume MA (20): 10302511.55
# Stochastic %K: 68.90
# Stochastic %D: 81.02
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.17/10
# ============================================================
#
# === Dixon Technologies (India) Limited (DIXON.NS) ===
# Fundamental Metrics:
# longName: Dixon Technologies (India) Limited
# sector: Technology
# industry: Consumer Electronics
# marketCap: 818824282112
# trailingPE: 96.15032
# forwardPE: 73.71767
# dividendYield: 0.03
# dividendRate: 5.0
# fiftyTwoWeekHigh: 19148.9
# fiftyTwoWeekLow: 7108.7
# returnOnEquity: N/A
# returnOnAssets: 0.05259996138140157
# debtToEquity: 30.83
# profitMargins: 0.02377
# operatingMargins: 0.03022
# grossMargins: 0.079239994
# ebitdaMargins: 0.03482
# bookValue: 393.424
# priceToBook: 34.630577
# revenueGrowth: 1.17
# earningsGrowth: 1.199
# trailingPegRatio: None
# enterpriseValue: 701344841728
# totalDebt: 7939800064
# totalRevenue: 332255297536
# revenuePerShare: 5890.734
#
# Computed ROE: N/A
# Computed ROA: 5.26%
# Fundamental Score: 6.00/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 13624.50
# 50-Day MA: 14569.46
# 200-Day MA: 14215.45
# RSI (14): 44.37
# MACD: -208.54
# MACD Signal: -331.39
# Bollinger Bands Score: 10.00
# ATR (14): 592.21
# Volume MA (20): 332465.75
# Stochastic %K: 43.94
# Stochastic %D: 68.32
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 7.12/10
# ============================================================
#
# === Container Corporation of India Limited (CONCOR.NS) ===
# Fundamental Metrics:
# longName: Container Corporation of India Limited
# sector: Industrials
# industry: Railroads
# marketCap: 433604100096
# trailingPE: 33.13082
# forwardPE: 25.406998
# dividendYield: 2.37
# dividendRate: 17.0
# fiftyTwoWeekHigh: 1180.0
# fiftyTwoWeekLow: 601.25
# returnOnEquity: N/A
# returnOnAssets: 0.08979814845947155
# debtToEquity: 7.45
# profitMargins: 0.14609
# operatingMargins: 0.17185
# grossMargins: 0.26195
# ebitdaMargins: 0.21691
# bookValue: 199.835
# priceToBook: 3.561188
# revenueGrowth: -0.001
# earningsGrowth: 0.109
# trailingPegRatio: None
# enterpriseValue: 407550001152
# totalDebt: 9149700096
# totalRevenue: 89472901120
# revenuePerShare: 146.845
#
# Computed ROE: N/A
# Computed ROA: 8.98%
# Fundamental Score: 5.65/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 711.65
# 50-Day MA: 702.01
# 200-Day MA: 856.58
# RSI (14): 75.20
# MACD: -0.86
# MACD Signal: -11.65
# Bollinger Bands Score: 10.00
# ATR (14): 21.86
# Volume MA (20): 1251393.10
# Stochastic %K: 81.63
# Stochastic %D: 91.07
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.19/10
# ============================================================
#
# === Chambal Fertilisers and Chemicals Limited (CHAMBLFERT.NS) ===
# Fundamental Metrics:
# longName: Chambal Fertilisers and Chemicals Limited
# sector: Basic Materials
# industry: Agricultural Inputs
# marketCap: 246140551168
# trailingPE: 15.187885
# forwardPE: 35.105713
# dividendYield: 1.29
# dividendRate: 8.0
# fiftyTwoWeekHigh: 622.6
# fiftyTwoWeekLow: 333.4
# returnOnEquity: N/A
# returnOnAssets: 0.11085266535580508
# debtToEquity: 1.215
# profitMargins: 0.09595
# operatingMargins: 0.14130001
# grossMargins: 0.43006
# ebitdaMargins: 0.14817001
# bookValue: 204.806
# priceToBook: 2.999668
# revenueGrowth: 0.131
# earningsGrowth: 0.208
# trailingPegRatio: None
# enterpriseValue: 220513304576
# totalDebt: 994499968
# totalRevenue: 168405106688
# revenuePerShare: 418.926
#
# Computed ROE: N/A
# Computed ROA: 11.09%
# Fundamental Score: 8.26/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 614.35
# 50-Day MA: 535.98
# 200-Day MA: 505.26
# RSI (14): 75.51
# MACD: 18.88
# MACD Signal: 15.37
# Bollinger Bands Score: 10.00
# ATR (14): 19.59
# Volume MA (20): 2469547.80
# Stochastic %K: 90.57
# Stochastic %D: 95.00
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 8.48/10
# ============================================================
#
# === Poonawalla Fincorp Limited (POONAWALLA.NS) ===
# Fundamental Metrics:
# longName: Poonawalla Fincorp Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 268361728000
# trailingPE: 161.18604
# forwardPE: 25.622921
# dividendYield: 1.3
# dividendRate: 4.0
# fiftyTwoWeekHigh: 514.0
# fiftyTwoWeekLow: 267.2
# returnOnEquity: N/A
# returnOnAssets: 0.06986162602908635
# debtToEquity: 225.886
# profitMargins: 0.13118
# operatingMargins: 0.07768
# grossMargins: 0.99857
# ebitdaMargins: 0.0
# bookValue: 103.808
# priceToBook: 3.3383746
# revenueGrowth: -0.406
# earningsGrowth: -0.93
# trailingPegRatio: None
# enterpriseValue: 450728722432
# totalDebt: 181070004224
# totalRevenue: 13037899776
# revenuePerShare: 16.89
#
# Computed ROE: N/A
# Computed ROA: 6.99%
# Fundamental Score: 5.16/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 346.55
# 50-Day MA: 302.94
# 200-Day MA: 358.11
# RSI (14): 85.87
# MACD: 9.99
# MACD Signal: 1.78
# Bollinger Bands Score: 4.00
# ATR (14): 11.73
# Volume MA (20): 2152138.00
# Stochastic %K: 90.53
# Stochastic %D: 92.69
#
# Technical Score: 5.80/10
#
# Composite Financial Strength Score: 5.41/10
# ============================================================
#
# === State Bank of India (SBIN.NS) ===
# Fundamental Metrics:
# longName: State Bank of India
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 6897392418816
# trailingPE: 8.690543
# forwardPE: 9.348615
# dividendYield: 1.75
# dividendRate: 13.7
# fiftyTwoWeekHigh: 912.0
# fiftyTwoWeekLow: 680.0
# returnOnEquity: 0.1816
# returnOnAssets: 0.009962410125944251
# debtToEquity: N/A
# profitMargins: 0.23271999
# operatingMargins: 0.28902
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 538.053
# priceToBook: 1.4363827
# revenueGrowth: 0.059
# earningsGrowth: 0.703
# trailingPegRatio: None
# enterpriseValue: 11186543263744
# totalDebt: 7560226144256
# totalRevenue: 3409518788608
# revenuePerShare: 382.042
#
# Computed ROE: 18.16%
# Computed ROA: 1.00%
# Fundamental Score: 8.26/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 772.85
# 50-Day MA: 740.77
# 200-Day MA: 801.82
# RSI (14): 77.47
# MACD: 6.77
# MACD Signal: -0.63
# Bollinger Bands Score: 10.00
# ATR (14): 12.87
# Volume MA (20): 8893371.70
# Stochastic %K: 80.94
# Stochastic %D: 91.80
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.76/10
# ============================================================
#
# === REC Limited (RECLTD.NS) ===
# Fundamental Metrics:
# longName: REC Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 1165858177024
# trailingPE: 7.467532
# forwardPE: 6.539882
# dividendYield: 3.46
# dividendRate: 15.4
# fiftyTwoWeekHigh: 654.0
# fiftyTwoWeekLow: 357.35
# returnOnEquity: 0.21976
# returnOnAssets: 0.02580388528387063
# debtToEquity: 678.386
# profitMargins: 0.74731004
# operatingMargins: 0.94655997
# grossMargins: 0.99274004
# ebitdaMargins: 0.0
# bookValue: 293.048
# priceToBook: 1.5108446
# revenueGrowth: 0.272
# earningsGrowth: 0.232
# trailingPegRatio: None
# enterpriseValue: 6210180874240
# totalDebt: 5234832179200
# totalRevenue: 209463197696
# revenuePerShare: 79.546
#
# Computed ROE: 21.98%
# Computed ROA: 2.58%
# Fundamental Score: 8.32/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 442.75
# 50-Day MA: 420.63
# 200-Day MA: 512.00
# RSI (14): 78.19
# MACD: 5.72
# MACD Signal: -1.09
# Bollinger Bands Score: 10.00
# ATR (14): 13.42
# Volume MA (20): 8261200.30
# Stochastic %K: 89.02
# Stochastic %D: 91.78
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.79/10
# ============================================================
#
# === ICICI Lombard General Insurance Company Limited (ICICIGI.NS) ===
# Fundamental Metrics:
# longName: ICICI Lombard General Insurance Company Limited
# sector: Financial Services
# industry: Insurance - Diversified
# marketCap: 881909497856
# trailingPE: 35.34962
# forwardPE: 30.528393
# dividendYield: 0.62
# dividendRate: 11.0
# fiftyTwoWeekHigh: 2301.9
# fiftyTwoWeekLow: 1480.5
# returnOnEquity: 0.18601
# returnOnAssets: 0.03030552865908964
# debtToEquity: N/A
# profitMargins: 0.10817
# operatingMargins: 0.15652001
# grossMargins: 0.26003
# ebitdaMargins: 0.14462
# bookValue: 292.415
# priceToBook: 6.085529
# revenueGrowth: 0.193
# earningsGrowth: 0.659
# trailingPegRatio: None
# enterpriseValue: 880974954496
# totalDebt: 0
# totalRevenue: 232810397696
# revenuePerShare: 471.699
#
# Computed ROE: 18.60%
# Computed ROA: 3.03%
# Fundamental Score: 6.88/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1779.50
# 50-Day MA: 1776.71
# 200-Day MA: 1907.36
# RSI (14): 72.00
# MACD: -2.10
# MACD Signal: -17.25
# Bollinger Bands Score: 10.00
# ATR (14): 46.60
# Volume MA (20): 894329.30
# Stochastic %K: 69.63
# Stochastic %D: 78.41
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.93/10
# ============================================================
#
# === Bank of Baroda Limited (BANKBARODA.NS) ===
# Fundamental Metrics:
# longName: Bank of Baroda Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 1153729167360
# trailingPE: 5.6459126
# forwardPE: 10.125737
# dividendYield: 3.39
# dividendRate: 7.6
# fiftyTwoWeekHigh: 299.7
# fiftyTwoWeekLow: 190.7
# returnOnEquity: 0.15798001
# returnOnAssets: 0.011341317806947818
# debtToEquity: N/A
# profitMargins: 0.32016
# operatingMargins: 0.43094003
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 270.34
# priceToBook: 0.82514614
# revenueGrowth: 0.06
# earningsGrowth: 0.089
# trailingPegRatio: None
# enterpriseValue: 2043385479168
# totalDebt: 1411515940864
# totalRevenue: 638094737408
# revenuePerShare: 123.378
#
# Computed ROE: 15.80%
# Computed ROA: 1.13%
# Fundamental Score: 8.52/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 223.07
# 50-Day MA: 213.57
# 200-Day MA: 241.17
# RSI (14): 84.39
# MACD: 1.81
# MACD Signal: -1.16
# Bollinger Bands Score: 10.00
# ATR (14): 4.75
# Volume MA (20): 9292501.40
# Stochastic %K: 90.57
# Stochastic %D: 94.91
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.91/10
# ============================================================
#
# === GAIL (India) Limited (GAIL.NS) ===
# Fundamental Metrics:
# longName: GAIL (India) Limited
# sector: Utilities
# industry: Utilities - Regulated Gas
# marketCap: 1168519593984
# trailingPE: 9.397144
# forwardPE: 10.533491
# dividendYield: 3.59
# dividendRate: 6.5
# fiftyTwoWeekHigh: 246.3
# fiftyTwoWeekLow: 150.52
# returnOnEquity: N/A
# returnOnAssets: 0.07937331513857387
# debtToEquity: 23.366
# profitMargins: 0.08991
# operatingMargins: 0.060539998
# grossMargins: 0.18885
# ebitdaMargins: 0.10962
# bookValue: 127.57
# priceToBook: 1.3929607
# revenueGrowth: 0.062
# earningsGrowth: 0.278
# trailingPegRatio: None
# enterpriseValue: 1357882851328
# totalDebt: 196317691904
# totalRevenue: 1382177177600
# revenuePerShare: 210.279
#
# Computed ROE: N/A
# Computed ROA: 7.94%
# Fundamental Score: 7.57/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 177.70
# 50-Day MA: 165.17
# 200-Day MA: 196.78
# RSI (14): 74.74
# MACD: 2.47
# MACD Signal: -0.49
# Bollinger Bands Score: 10.00
# ATR (14): 5.52
# Volume MA (20): 13621314.50
# Stochastic %K: 73.95
# Stochastic %D: 83.73
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.34/10
# ============================================================
#
# === Tech Mahindra Limited (TECHM.NS) ===
# Fundamental Metrics:
# longName: Tech Mahindra Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 1287765229568
# trailingPE: 34.531433
# forwardPE: 22.506573
# dividendYield: 2.95
# dividendRate: 43.0
# fiftyTwoWeekHigh: 1807.7
# fiftyTwoWeekLow: 1162.95
# returnOnEquity: N/A
# returnOnAssets: 0.054297663021951194
# debtToEquity: 7.566
# profitMargins: 0.07138
# operatingMargins: 0.10163
# grossMargins: 0.3048
# ebitdaMargins: 0.11293
# bookValue: 298.711
# priceToBook: 4.8726025
# revenueGrowth: 0.014
# earningsGrowth: 0.924
# trailingPegRatio: None
# enterpriseValue: 1254404259840
# totalDebt: 20351000576
# totalRevenue: 524755992576
# revenuePerShare: 592.47
#
# Computed ROE: N/A
# Computed ROA: 5.43%
# Fundamental Score: 6.35/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1455.50
# 50-Day MA: 1596.36
# 200-Day MA: 1595.47
# RSI (14): 43.81
# MACD: -52.45
# MACD Signal: -55.11
# Bollinger Bands Score: 10.00
# ATR (14): 38.40
# Volume MA (20): 2269520.85
# Stochastic %K: 43.53
# Stochastic %D: 35.01
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 7.33/10
# ============================================================
#
# === Hindustan Copper Limited (HINDCOPPER.NS) ===
# Fundamental Metrics:
# longName: Hindustan Copper Limited
# sector: Basic Materials
# industry: Copper
# marketCap: 221493035008
# trailingPE: 55.033657
# forwardPE: N/A
# dividendYield: 0.39
# dividendRate: 0.92
# fiftyTwoWeekHigh: 415.8
# fiftyTwoWeekLow: 195.4
# returnOnEquity: N/A
# returnOnAssets: 0.09030589599825961
# debtToEquity: 3.8
# profitMargins: 0.21117
# operatingMargins: 0.26159
# grossMargins: 1.02265
# ebitdaMargins: 0.38188
# bookValue: 24.899
# priceToBook: 9.194747
# revenueGrowth: -0.179
# earningsGrowth: 0.0
# trailingPegRatio: None
# enterpriseValue: 229145280512
# totalDebt: 915000000
# totalRevenue: 19049261056
# revenuePerShare: 19.662
#
# Computed ROE: N/A
# Computed ROA: 9.03%
# Fundamental Score: 5.33/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 228.94
# 50-Day MA: 226.99
# 200-Day MA: 284.12
# RSI (14): 69.62
# MACD: 1.03
# MACD Signal: -1.74
# Bollinger Bands Score: 10.00
# ATR (14): 9.65
# Volume MA (20): 5235315.25
# Stochastic %K: 68.84
# Stochastic %D: 81.28
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.24/10
# ============================================================
#
# === Indian Energy Exchange Limited (IEX.NS) ===
# Fundamental Metrics:
# longName: Indian Energy Exchange Limited
# sector: Financial Services
# industry: Capital Markets
# marketCap: 156523577344
# trailingPE: 38.34205
# forwardPE: 39.548317
# dividendYield: 1.68
# dividendRate: 3.0
# fiftyTwoWeekHigh: 244.4
# fiftyTwoWeekLow: 133.15
# returnOnEquity: N/A
# returnOnAssets: 0.19777331606809176
# debtToEquity: 0.784
# profitMargins: 0.64668
# operatingMargins: 0.84831
# grossMargins: 0.99821
# ebitdaMargins: 0.84899
# bookValue: 11.763
# priceToBook: 14.961321
# revenueGrowth: 0.137
# earningsGrowth: 0.175
# trailingPegRatio: None
# enterpriseValue: 147188416512
# totalDebt: 81839000
# totalRevenue: 6320589824
# revenuePerShare: 7.104
#
# Computed ROE: N/A
# Computed ROA: 19.78%
# Fundamental Score: 7.04/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 175.99
# 50-Day MA: 167.36
# 200-Day MA: 180.88
# RSI (14): 73.73
# MACD: 1.52
# MACD Signal: -0.95
# Bollinger Bands Score: 10.00
# ATR (14): 5.23
# Volume MA (20): 5663779.60
# Stochastic %K: 85.55
# Stochastic %D: 94.21
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.03/10
# ============================================================
#
# === Housing and Urban Development Corporation Limited (HUDCO.NS) ===
# Fundamental Metrics:
# longName: Housing and Urban Development Corporation Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 408447647744
# trailingPE: 15.2488785
# forwardPE: 12.365455
# dividendYield: 1.48
# dividendRate: 3.1
# fiftyTwoWeekHigh: 353.7
# fiftyTwoWeekLow: 158.85
# returnOnEquity: N/A
# returnOnAssets: 0.022657214537764737
# debtToEquity: 546.443
# profitMargins: 0.68615997
# operatingMargins: 0.90939003
# grossMargins: 0.99616
# ebitdaMargins: 0.0
# bookValue: 85.536
# priceToBook: 2.3853114
# revenueGrowth: 0.332
# earningsGrowth: 0.417
# trailingPegRatio: None
# enterpriseValue: 1337180160000
# totalDebt: 935653212160
# totalRevenue: 39080599552
# revenuePerShare: 19.517
#
# Computed ROE: N/A
# Computed ROA: 2.27%
# Fundamental Score: 7.43/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 204.03
# 50-Day MA: 196.99
# 200-Day MA: 238.05
# RSI (14): 80.91
# MACD: 2.76
# MACD Signal: -1.61
# Bollinger Bands Score: 7.00
# ATR (14): 7.61
# Volume MA (20): 7201285.85
# Stochastic %K: 81.14
# Stochastic %D: 90.17
#
# Technical Score: 6.40/10
#
# Composite Financial Strength Score: 7.02/10
# ============================================================
#
# === Power Grid Corporation of India Limited (POWERGRID.NS) ===
# Fundamental Metrics:
# longName: Power Grid Corporation of India Limited
# sector: Utilities
# industry: Utilities - Regulated Electric
# marketCap: 2706940362752
# trailingPE: 17.466988
# forwardPE: 13.681241
# dividendYield: 5.14
# dividendRate: 15.0
# fiftyTwoWeekHigh: 366.25
# fiftyTwoWeekLow: 247.3
# returnOnEquity: N/A
# returnOnAssets: 0.062071536222253434
# debtToEquity: 137.073
# profitMargins: 0.34168
# operatingMargins: 0.56279
# grossMargins: 0.97960997
# ebitdaMargins: 0.86168
# bookValue: 99.026
# priceToBook: 2.9386222
# revenueGrowth: -0.027
# earningsGrowth: -0.042
# trailingPegRatio: None
# enterpriseValue: 3888053223424
# totalDebt: 1261904592896
# totalRevenue: 454950813696
# revenuePerShare: 48.917
#
# Computed ROE: N/A
# Computed ROA: 6.21%
# Fundamental Score: 7.43/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 291.00
# 50-Day MA: 275.19
# 200-Day MA: 310.50
# RSI (14): 84.01
# MACD: 3.82
# MACD Signal: -0.16
# Bollinger Bands Score: 10.00
# ATR (14): 7.62
# Volume MA (20): 15435918.95
# Stochastic %K: 89.24
# Stochastic %D: 92.98
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.26/10
# ============================================================
#
# === Bosch Limited (BOSCHLTD.NS) ===
# Fundamental Metrics:
# longName: Bosch Limited
# sector: Consumer Cyclical
# industry: Auto Parts
# marketCap: 809567977472
# trailingPE: 39.946007
# forwardPE: 35.099815
# dividendYield: 1.2
# dividendRate: 340.0
# fiftyTwoWeekHigh: 39088.8
# fiftyTwoWeekLow: 26005.0
# returnOnEquity: N/A
# returnOnAssets: 0.14360319335965646
# debtToEquity: 0.247
# profitMargins: 0.11766
# operatingMargins: 0.107889995
# grossMargins: 0.34393
# ebitdaMargins: 0.13254
# bookValue: 4317.642
# priceToBook: 6.357197
# revenueGrowth: 0.062
# earningsGrowth: -0.115
# trailingPegRatio: None
# enterpriseValue: 799387615232
# totalDebt: 314000000
# totalRevenue: 172166004736
# revenuePerShare: 5836.959
#
# Computed ROE: N/A
# Computed ROA: 14.36%
# Fundamental Score: 6.86/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 27448.10
# 50-Day MA: 28141.90
# 200-Day MA: 32891.51
# RSI (14): 61.76
# MACD: -165.43
# MACD Signal: -410.01
# Bollinger Bands Score: 10.00
# ATR (14): 663.27
# Volume MA (20): 24073.20
# Stochastic %K: 57.84
# Stochastic %D: 76.92
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.91/10
# ============================================================
#
# === Tata Elxsi Limited (TATAELXSI.NS) ===
# Fundamental Metrics:
# longName: Tata Elxsi Limited
# sector: Technology
# industry: Software - Application
# marketCap: 342372581376
# trailingPE: 42.267975
# forwardPE: 37.367474
# dividendYield: 1.24
# dividendRate: 70.0
# fiftyTwoWeekHigh: 9080.0
# fiftyTwoWeekLow: 5157.7
# returnOnEquity: N/A
# returnOnAssets: 0.2485856523300919
# debtToEquity: 8.276
# profitMargins: 0.21654
# operatingMargins: 0.23493999
# grossMargins: 0.38589
# ebitdaMargins: 0.26397
# bookValue: 399.27
# priceToBook: 13.767502
# revenueGrowth: 0.027
# earningsGrowth: -0.036
# trailingPegRatio: None
# enterpriseValue: 339563249664
# totalDebt: 2057787008
# totalRevenue: 37381812224
# revenuePerShare: 600.191
#
# Computed ROE: N/A
# Computed ROA: 24.86%
# Fundamental Score: 6.67/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5496.95
# 50-Day MA: 5913.90
# 200-Day MA: 6840.91
# RSI (14): 54.14
# MACD: -152.63
# MACD Signal: -198.43
# Bollinger Bands Score: 10.00
# ATR (14): 164.28
# Volume MA (20): 166922.00
# Stochastic %K: 57.97
# Stochastic %D: 67.62
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 7.04/10
# ============================================================
#
# === Macrotech Developers Limited (LODHA.NS) ===
# Fundamental Metrics:
# longName: Macrotech Developers Limited
# sector: Real Estate
# industry: Real Estate - Development
# marketCap: 1207255826432
# trailingPE: 47.799294
# forwardPE: 36.371136
# dividendYield: 0.18
# dividendRate: 2.25
# fiftyTwoWeekHigh: 1649.95
# fiftyTwoWeekLow: 1035.15
# returnOnEquity: 0.15777001
# returnOnAssets: 0.032802402107349464
# debtToEquity: 43.778
# profitMargins: 0.18478
# operatingMargins: 0.30337998
# grossMargins: 0.38598
# ebitdaMargins: 0.27271998
# bookValue: 182.749
# priceToBook: 6.6200094
# revenueGrowth: 0.393
# earningsGrowth: 0.817
# trailingPegRatio: None
# enterpriseValue: 1266837749760
# totalDebt: 79896002560
# totalRevenue: 135736999936
# revenuePerShare: 137.088
#
# Computed ROE: 15.78%
# Computed ROA: 3.28%
# Fundamental Score: 6.52/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1209.80
# 50-Day MA: 1161.46
# 200-Day MA: 1279.36
# RSI (14): 60.45
# MACD: 0.30
# MACD Signal: -15.46
# Bollinger Bands Score: 10.00
# ATR (14): 55.45
# Volume MA (20): 1497309.10
# Stochastic %K: 80.91
# Stochastic %D: 80.43
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.95/10
# ============================================================
#
# === Punjab National Bank (PNB.NS) ===
# Fundamental Metrics:
# longName: Punjab National Bank
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 1078374105088
# trailingPE: 6.2125826
# forwardPE: 6.676868
# dividendYield: 1.56
# dividendRate: 1.5
# fiftyTwoWeekHigh: 142.9
# fiftyTwoWeekLow: 85.46
# returnOnEquity: 0.14027001
# returnOnAssets: 0.005696856712769053
# debtToEquity: N/A
# profitMargins: 0.32672
# operatingMargins: 0.47184
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 114.203
# priceToBook: 0.821432
# revenueGrowth: 0.446
# earningsGrowth: 0.891
# trailingPegRatio: None
# enterpriseValue: 1388718850048
# totalDebt: 901469372416
# totalRevenue: 515221585920
# revenuePerShare: 46.239
#
# Computed ROE: 14.03%
# Computed ROA: 0.57%
# Fundamental Score: 8.26/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 93.81
# 50-Day MA: 94.56
# 200-Day MA: 106.64
# RSI (14): 67.23
# MACD: -0.49
# MACD Signal: -1.53
# Bollinger Bands Score: 10.00
# ATR (14): 2.33
# Volume MA (20): 20044860.65
# Stochastic %K: 74.40
# Stochastic %D: 89.15
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.76/10
# ============================================================
#
# === NMDC Limited (NMDC.NS) ===
# Fundamental Metrics:
# longName: NMDC Limited
# sector: Basic Materials
# industry: Steel
# marketCap: 599686709248
# trailingPE: 9.252375
# forwardPE: 2.644048
# dividendYield: 4.03
# dividendRate: 2.8
# fiftyTwoWeekHigh: 95.45
# fiftyTwoWeekLow: 59.7
# returnOnEquity: N/A
# returnOnAssets: 0.15633480020066723
# debtToEquity: 14.651
# profitMargins: 0.27691
# operatingMargins: 0.34552
# grossMargins: 0.53150004
# ebitdaMargins: 0.34916002
# bookValue: 32.266
# priceToBook: 2.1133702
# revenueGrowth: 0.214
# earningsGrowth: 0.269
# trailingPegRatio: None
# enterpriseValue: 510337318912
# totalDebt: 41577299968
# totalRevenue: 233902407680
# revenuePerShare: 26.622
#
# Computed ROE: N/A
# Computed ROA: 15.63%
# Fundamental Score: 9.22/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 68.19
# 50-Day MA: 63.16
# 200-Day MA: 70.61
# RSI (14): 73.37
# MACD: 1.27
# MACD Signal: 0.57
# Bollinger Bands Score: 10.00
# ATR (14): 2.23
# Volume MA (20): 23344267.10
# Stochastic %K: 77.74
# Stochastic %D: 88.12
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 8.33/10
# ============================================================
#
# === IDFC First Bank Limited (IDFCFIRSTB.NS) ===
# Fundamental Metrics:
# longName: IDFC First Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 419900063744
# trailingPE: 21.560148
# forwardPE: 12.32321
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 86.1
# fiftyTwoWeekLow: 52.6
# returnOnEquity: 0.05869
# returnOnAssets: 0.00993333919253671
# debtToEquity: N/A
# profitMargins: 0.096920006
# operatingMargins: 0.078990005
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 51.758
# priceToBook: 1.1080413
# revenueGrowth: 0.038
# earningsGrowth: -0.553
# trailingPegRatio: None
# enterpriseValue: 729231065088
# totalDebt: 463983706112
# totalRevenue: 198785548288
# revenuePerShare: 27.517
#
# Computed ROE: 5.87%
# Computed ROA: 0.99%
# Fundamental Score: 5.90/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 57.35
# 50-Day MA: 59.71
# 200-Day MA: 68.44
# RSI (14): 52.22
# MACD: -1.12
# MACD Signal: -1.50
# Bollinger Bands Score: 10.00
# ATR (14): 1.39
# Volume MA (20): 26372565.25
# Stochastic %K: 78.90
# Stochastic %D: 75.30
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.58/10
# ============================================================
#
# === JSW Energy Limited (JSWENERGY.NS) ===
# Fundamental Metrics:
# longName: JSW Energy Limited
# sector: Utilities
# industry: Utilities - Independent Power Producers
# marketCap: 969180119040
# trailingPE: 50.5323
# forwardPE: 88.9984
# dividendYield: 0.35
# dividendRate: 2.0
# fiftyTwoWeekHigh: 804.9
# fiftyTwoWeekLow: 418.75
# returnOnEquity: N/A
# returnOnAssets: 0.029564726415887668
# debtToEquity: 109.09
# profitMargins: 0.16745001
# operatingMargins: 0.20838
# grossMargins: 0.57083
# ebitdaMargins: 0.45771
# bookValue: 160.629
# priceToBook: 3.4573457
# revenueGrowth: -0.041
# earningsGrowth: -0.319
# trailingPegRatio: None
# enterpriseValue: 1251317383168
# totalDebt: 308530610176
# totalRevenue: 113118699520
# revenuePerShare: 65.828
#
# Computed ROE: N/A
# Computed ROA: 2.96%
# Fundamental Score: 5.62/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 555.35
# 50-Day MA: 505.16
# 200-Day MA: 646.85
# RSI (14): 71.42
# MACD: 18.63
# MACD Signal: 10.44
# Bollinger Bands Score: 10.00
# ATR (14): 21.55
# Volume MA (20): 4789497.10
# Stochastic %K: 76.29
# Stochastic %D: 86.70
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.17/10
# ============================================================
#
# === Persistent Systems Limited (PERSISTENT.NS) ===
# Fundamental Metrics:
# longName: Persistent Systems Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 856823037952
# trailingPE: 65.30724
# forwardPE: 100.602715
# dividendYield: 0.55
# dividendRate: 30.0
# fiftyTwoWeekHigh: 6788.9
# fiftyTwoWeekLow: 3232.05
# returnOnEquity: 0.24133
# returnOnAssets: 0.14829775559298028
# debtToEquity: 7.764
# profitMargins: 0.11659
# operatingMargins: 0.14385
# grossMargins: 0.27
# ebitdaMargins: 0.15414
# bookValue: 397.262
# priceToBook: 13.991522
# revenueGrowth: 0.226
# earningsGrowth: 0.287
# trailingPegRatio: None
# enterpriseValue: 827002912768
# totalDebt: 4738719744
# totalRevenue: 113192337408
# revenuePerShare: 740.119
#
# Computed ROE: 24.13%
# Computed ROA: 14.83%
# Fundamental Score: 6.81/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5558.30
# 50-Day MA: 5699.01
# 200-Day MA: 5377.32
# RSI (14): 66.15
# MACD: -103.88
# MACD Signal: -158.53
# Bollinger Bands Score: 10.00
# ATR (14): 212.59
# Volume MA (20): 592388.50
# Stochastic %K: 88.38
# Stochastic %D: 76.13
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 7.61/10
# ============================================================
#
# === Indraprastha Gas Limited (IGL.NS) ===
# Fundamental Metrics:
# longName: Indraprastha Gas Limited
# sector: Utilities
# industry: Utilities - Regulated Gas
# marketCap: 279159996416
# trailingPE: 16.438581
# forwardPE: 6.83579
# dividendYield: 2.58
# dividendRate: 5.25
# fiftyTwoWeekHigh: 285.175
# fiftyTwoWeekLow: 153.05
# returnOnEquity: N/A
# returnOnAssets: 0.13959743909265568
# debtToEquity: 0.7
# profitMargins: 0.11655
# operatingMargins: 0.063930005
# grossMargins: 0.23948999
# ebitdaMargins: 0.13262999
# bookValue: 75.505
# priceToBook: 2.6408846
# revenueGrowth: 0.057
# earningsGrowth: -0.314
# trailingPegRatio: None
# enterpriseValue: 254307745792
# totalDebt: 741800000
# totalRevenue: 145552900096
# revenuePerShare: 104.052
#
# Computed ROE: N/A
# Computed ROA: 13.96%
# Fundamental Score: 8.00/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 199.40
# 50-Day MA: 194.00
# 200-Day MA: 221.76
# RSI (14): 71.01
# MACD: 1.18
# MACD Signal: -0.77
# Bollinger Bands Score: 10.00
# ATR (14): 6.54
# Volume MA (20): 4219040.10
# Stochastic %K: 67.83
# Stochastic %D: 79.27
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.60/10
# ============================================================
#
# === Info Edge (India) Limited (NAUKRI.NS) ===
# Fundamental Metrics:
# longName: Info Edge (India) Limited
# sector: Communication Services
# industry: Internet Content & Information
# marketCap: 924489285632
# trailingPE: 164.95152
# forwardPE: 76.506424
# dividendYield: 0.34
# ...
# trailingPE: 50.429012
# forwardPE: 37.27222
# dividendYield: 0.64
# dividendRate: 3.2
# fiftyTwoWeekHigh: 768.65
# fiftyTwoWeekLow: 464.05
# returnOnEquity: N/A
# returnOnAssets: 0.13383664781070104
# debtToEquity: 3.744
# profitMargins: 0.16429001
# operatingMargins: 0.19313
# grossMargins: 0.54763
# ebitdaMargins: 0.26429
# bookValue: 87.934
# priceToBook: 5.6144385
# revenueGrowth: 0.11
# earningsGrowth: 0.075
# trailingPegRatio: None
# enterpriseValue: 286493868032
# totalDebt: 2015040000
# totalRevenue: 35653951488
# revenuePerShare: 59.694
#
# Computed ROE: N/A
# Computed ROA: 13.38%
# Fundamental Score: 6.09/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 493.70
# 50-Day MA: 513.78
# 200-Day MA: 630.51
# RSI (14): 57.93
# MACD: -4.45
# MACD Signal: -5.71
# Bollinger Bands Score: 10.00
# ATR (14): 18.90
# Volume MA (20): 1391654.85
# Stochastic %K: 37.95
# Stochastic %D: 53.20
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.69/10
# ============================================================
#
# === InterGlobe Aviation Limited (INDIGO.NS) ===
# Fundamental Metrics:
# longName: InterGlobe Aviation Limited
# sector: Industrials
# industry: Airlines
# marketCap: 1934704115712
# trailingPE: 31.776468
# forwardPE: 24.369434
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 5190.35
# fiftyTwoWeekLow: 3302.35
# returnOnEquity: N/A
# returnOnAssets: 0.09939210710109735
# debtToEquity: 1558.415
# profitMargins: 0.07958
# operatingMargins: 0.19943
# grossMargins: 0.32027
# ebitdaMargins: 0.13467
# bookValue: 98.427
# priceToBook: 50.86714
# revenueGrowth: 0.137
# earningsGrowth: -0.184
# trailingPegRatio: None
# enterpriseValue: 2152358871040
# totalDebt: 592369025024
# totalRevenue: 764762390528
# revenuePerShare: 1980.613
#
# Computed ROE: N/A
# Computed ROA: 9.94%
# Fundamental Score: 5.90/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5006.70
# 50-Day MA: 4449.15
# 200-Day MA: 4438.26
# RSI (14): 71.09
# MACD: 159.32
# MACD Signal: 131.99
# Bollinger Bands Score: 10.00
# ATR (14): 119.30
# Volume MA (20): 983841.40
# Stochastic %K: 70.50
# Stochastic %D: 75.39
#
# Technical Score: 8.80/10
#
# Composite Financial Strength Score: 7.06/10
# ============================================================
#
# === Glenmark Pharmaceuticals Limited (GLENMARK.NS) ===
# Fundamental Metrics:
# longName: Glenmark Pharmaceuticals Limited
# sector: Healthcare
# industry: Drug Manufacturers - Specialty & Generic
# marketCap: 417975730176
# trailingPE: N/A
# forwardPE: 34.857582
# dividendYield: 0.17
# dividendRate: 2.5
# fiftyTwoWeekHigh: 1830.95
# fiftyTwoWeekLow: 936.0
# returnOnEquity: N/A
# returnOnAssets: -0.10458300182524453
# debtToEquity: 21.086
# profitMargins: -0.0125899995
# operatingMargins: 0.14095001
# grossMargins: 0.68301004
# ebitdaMargins: 0.21981001
# bookValue: 598.469
# priceToBook: 2.47423
# revenueGrowth: 0.351
# earningsGrowth: N/A
# trailingPegRatio: None
# enterpriseValue: 420841652224
# totalDebt: 17808490496
# totalRevenue: 139607703552
# revenuePerShare: 494.838
#
# Computed ROE: N/A
# Computed ROA: -10.46%
# Fundamental Score: 6.95/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1480.75
# 50-Day MA: 1425.41
# 200-Day MA: 1515.68
# RSI (14): 76.83
# MACD: 21.89
# MACD Signal: 6.17
# Bollinger Bands Score: 10.00
# ATR (14): 36.86
# Volume MA (20): 518349.50
# Stochastic %K: 80.71
# Stochastic %D: 89.21
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.97/10
# ============================================================
#
# === J.K. Cement Limited (JKCEMENT.NS) ===
# Fundamental Metrics:
# longName: J.K. Cement Limited
# sector: Basic Materials
# industry: Building Materials
# marketCap: 366966013952
# trailingPE: 50.853947
# forwardPE: 68.383736
# dividendYield: 0.32
# dividendRate: 15.0
# fiftyTwoWeekHigh: 4988.95
# fiftyTwoWeekLow: 3642.0
# returnOnEquity: N/A
# returnOnAssets: 0.05342687861857439
# debtToEquity: 104.504
# profitMargins: 0.06318
# operatingMargins: 0.118240006
# grossMargins: 0.61866003
# ebitdaMargins: 0.16266
# bookValue: 714.952
# priceToBook: 6.6427536
# revenueGrowth: -0.002
# earningsGrowth: -0.332
# trailingPegRatio: None
# enterpriseValue: 417604042752
# totalDebt: 57380298752
# totalRevenue: 114037399552
# revenuePerShare: 1475.273
#
# Computed ROE: N/A
# Computed ROA: 5.34%
# Fundamental Score: 5.33/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4749.25
# 50-Day MA: 4625.65
# 200-Day MA: 4464.76
# RSI (14): 67.49
# MACD: 19.91
# MACD Signal: -32.74
# Bollinger Bands Score: 10.00
# ATR (14): 123.87
# Volume MA (20): 119831.80
# Stochastic %K: 81.78
# Stochastic %D: 85.60
#
# Technical Score: 9.40/10
#
# Composite Financial Strength Score: 6.96/10
# ============================================================
#
# === Trent Limited (TRENT.NS) ===
# Fundamental Metrics:
# longName: Trent Limited
# sector: Consumer Cyclical
# industry: Apparel Retail
# marketCap: 1843238535168
# trailingPE: 94.981674
# forwardPE: 76.11641
# dividendYield: 0.06
# dividendRate: 3.2
# fiftyTwoWeekHigh: 8345.0
# fiftyTwoWeekLow: 3843.0
# returnOnEquity: N/A
# returnOnAssets: 0.207602890355011
# debtToEquity: 39.033
# profitMargins: 0.1192
# operatingMargins: 0.12821001
# grossMargins: 0.42917
# ebitdaMargins: 0.124469995
# bookValue: 133.103
# priceToBook: 38.95517
# revenueGrowth: 0.343
# earningsGrowth: 0.329
# trailingPegRatio: None
# enterpriseValue: 1805525057536
# totalDebt: 18421999616
# totalRevenue: 162153693184
# revenuePerShare: 456.205
#
# Computed ROE: N/A
# Computed ROA: 20.76%
# Fundamental Score: 6.26/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5185.05
# 50-Day MA: 5360.23
# 200-Day MA: 6299.06
# RSI (14): 58.05
# MACD: -56.18
# MACD Signal: -106.65
# Bollinger Bands Score: 10.00
# ATR (14): 169.77
# Volume MA (20): 1114570.95
# Stochastic %K: 77.40
# Stochastic %D: 68.17
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.80/10
# ============================================================
#
# === L&T Technology Services Limited (LTTS.NS) ===
# Fundamental Metrics:
# longName: L&T Technology Services Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 489543008256
# trailingPE: 37.829624
# forwardPE: 31.307453
# dividendYield: 1.09
# dividendRate: 50.0
# fiftyTwoWeekHigh: 6000.0
# fiftyTwoWeekLow: 4200.0
# returnOnEquity: N/A
# returnOnAssets: 0.15358426105907994
# debtToEquity: 11.42
# profitMargins: 0.12681
# operatingMargins: 0.15903
# grossMargins: 0.46967
# ebitdaMargins: 0.17243
# bookValue: 531.014
# priceToBook: 8.709846
# revenueGrowth: 0.095
# earningsGrowth: -0.042
# trailingPegRatio: None
# enterpriseValue: 464482795520
# totalDebt: 6441999872
# totalRevenue: 102253002752
# revenuePerShare: 966.468
#
# Computed ROE: N/A
# Computed ROA: 15.36%
# Fundamental Score: 6.29/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4625.05
# 50-Day MA: 5000.04
# 200-Day MA: 5119.00
# RSI (14): 52.44
# MACD: -110.12
# MACD Signal: -134.84
# Bollinger Bands Score: 10.00
# ATR (14): 171.29
# Volume MA (20): 136458.75
# Stochastic %K: 54.70
# Stochastic %D: 54.65
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.81/10
# ============================================================
#
# === Max Healthcare Institute Limited (MAXHEALTH.NS) ===
# Fundamental Metrics:
# longName: Max Healthcare Institute Limited
# sector: Healthcare
# industry: Medical Care Facilities
# marketCap: 1140179206144
# trailingPE: 113.63857
# forwardPE: 61.020756
# dividendYield: 0.13
# dividendRate: 1.5
# fiftyTwoWeekHigh: 1227.95
# fiftyTwoWeekLow: 737.5
# returnOnEquity: N/A
# returnOnAssets: 0.08813710735220343
# debtToEquity: 20.095
# profitMargins: 0.15415
# operatingMargins: 0.21495001
# grossMargins: 0.62341
# ebitdaMargins: 0.24925
# bookValue: 90.548
# priceToBook: 12.9516945
# revenueGrowth: 0.4
# earningsGrowth: -0.178
# trailingPegRatio: None
# enterpriseValue: 1117520003072
# totalDebt: 17681899520
# totalRevenue: 65416200192
# revenuePerShare: 67.31
#
# Computed ROE: N/A
# Computed ROA: 8.81%
# Fundamental Score: 6.19/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1172.75
# 50-Day MA: 1048.38
# 200-Day MA: 993.38
# RSI (14): 76.52
# MACD: 26.55
# MACD Signal: 2.51
# Bollinger Bands Score: 4.00
# ATR (14): 39.56
# Volume MA (20): 2632582.85
# Stochastic %K: 92.86
# Stochastic %D: 89.27
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.75/10
# ============================================================
#
# === Eternal Limited (ZOMATO.NS) ===
# Fundamental Metrics:
# longName: Eternal Limited
# sector: Consumer Cyclical
# industry: Internet Retail
# marketCap: 1901921435648
# trailingPE: 276.0658
# forwardPE: 83.257935
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 304.7
# fiftyTwoWeekLow: 146.3
# returnOnEquity: N/A
# returnOnAssets: 0.015028258263401267
# debtToEquity: 5.439
# profitMargins: 0.03689
# operatingMargins: -0.01573
# grossMargins: 0.60199
# ebitdaMargins: 0.01505
# bookValue: 24.442
# priceToBook: 8.583995
# revenueGrowth: 0.644
# earningsGrowth: -0.625
# trailingPegRatio: None
# enterpriseValue: 1935918891008
# totalDebt: 11589999616
# totalRevenue: 179719995392
# revenuePerShare: 20.555
#
# Computed ROE: N/A
# Computed ROA: 1.50%
# Fundamental Score: 5.05/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 209.81
# 50-Day MA: 222.95
# 200-Day MA: 245.71
# RSI (14): 37.28
# MACD: -2.77
# MACD Signal: -3.84
# Bollinger Bands Score: 10.00
# ATR (14): 9.53
# Volume MA (20): 58250730.35
# Stochastic %K: 32.66
# Stochastic %D: 64.07
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 5.83/10
# ============================================================
#
# === IndusInd Bank Limited (INDUSINDBK.NS) ===
# Fundamental Metrics:
# longName: IndusInd Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 496296361984
# trailingPE: 6.8463187
# forwardPE: 6.596086
# dividendYield: 2.46
# dividendRate: 16.5
# fiftyTwoWeekHigh: 1576.35
# fiftyTwoWeekLow: 606.0
# returnOnEquity: N/A
# returnOnAssets: 0.017428454813456076
# debtToEquity: N/A
# profitMargins: 0.28699
# operatingMargins: 0.31801
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 843.423
# priceToBook: 0.75531495
# revenueGrowth: -0.131
# earningsGrowth: -0.391
# trailingPegRatio: None
# enterpriseValue: 508245999616
# totalDebt: 447161204736
# totalRevenue: 252749086720
# revenuePerShare: 324.631
#
# Computed ROE: N/A
# Computed ROA: 1.74%
# Fundamental Score: 7.88/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 637.05
# 50-Day MA: 935.01
# 200-Day MA: 1183.52
# RSI (14): 11.42
# MACD: -93.87
# MACD Signal: -78.20
# Bollinger Bands Score: 7.00
# ATR (14): 49.94
# Volume MA (20): 22032054.00
# Stochastic %K: 7.98
# Stochastic %D: 14.76
#
# Technical Score: 4.60/10
#
# Composite Financial Strength Score: 6.57/10
# ============================================================
#
# === BSE Limited (BSE.NS) ===
# Fundamental Metrics:
# longName: BSE Limited
# sector: Financial Services
# industry: Financial Data & Stock Exchanges
# marketCap: 629721726976
# trailingPE: 67.97676
# forwardPE: 51.223984
# dividendYield: 0.32
# dividendRate: 15.0
# fiftyTwoWeekHigh: 6133.4
# fiftyTwoWeekLow: 2115.0
# returnOnEquity: N/A
# returnOnAssets: 0.08236730746235806
# debtToEquity: 0.0
# profitMargins: 0.32810003
# operatingMargins: 0.67991996
# grossMargins: 0.99568003
# ebitdaMargins: 0.56479
# bookValue: 343.489
# priceToBook: 13.542355
# revenueGrowth: 0.952
# earningsGrowth: 1.03
# trailingPegRatio: None
# enterpriseValue: 573346480128
# totalDebt: 200000
# totalRevenue: 28604499968
# revenuePerShare: 208.29
#
# Computed ROE: N/A
# Computed ROA: 8.24%
# Fundamental Score: 7.30/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4651.65
# 50-Day MA: 5117.85
# 200-Day MA: 4072.99
# RSI (14): 55.16
# MACD: -179.98
# MACD Signal: -276.07
# Bollinger Bands Score: 10.00
# ATR (14): 239.98
# Volume MA (20): 4867570.15
# Stochastic %K: 79.03
# Stochastic %D: 84.11
#
# Technical Score: 9.40/10
#
# Composite Financial Strength Score: 8.14/10
# ============================================================
#
# === Titan Company Limited (TITAN.NS) ===
# Fundamental Metrics:
# longName: Titan Company Limited
# sector: Consumer Cyclical
# industry: Luxury Goods
# marketCap: 2708769341440
# trailingPE: 84.0545
# forwardPE: 54.35564
# dividendYield: 0.36
# dividendRate: 11.0
# fiftyTwoWeekHigh: 3867.0
# fiftyTwoWeekLow: 2985.05
# returnOnEquity: N/A
# returnOnAssets: 0.11080824088748019
# debtToEquity: 222.35
# profitMargins: 0.05578
# operatingMargins: 0.0845
# grossMargins: 0.21246
# ebitdaMargins: 0.08558
# bookValue: 109.807
# priceToBook: 27.809702
# revenueGrowth: 0.252
# earningsGrowth: -0.008
# trailingPegRatio: None
# enterpriseValue: 2916248977408
# totalDebt: 216480006144
# totalRevenue: 580340023296
# revenuePerShare: 654.297
#
# Computed ROE: N/A
# Computed ROA: 11.08%
# Fundamental Score: 5.90/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 3053.70
# 50-Day MA: 3245.64
# 200-Day MA: 3384.51
# RSI (14): 50.48
# MACD: -44.65
# MACD Signal: -58.81
# Bollinger Bands Score: 10.00
# ATR (14): 62.27
# Volume MA (20): 857588.55
# Stochastic %K: 31.21
# Stochastic %D: 51.58
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.58/10
# ============================================================
#
# === Vodafone Idea Limited (IDEA.NS) ===
# Fundamental Metrics:
# longName: Vodafone Idea Limited
# sector: Communication Services
# industry: Telecom Services
# marketCap: 510459969536
# trailingPE: N/A
# forwardPE: -1.9015958
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 19.18
# fiftyTwoWeekLow: 6.61
# returnOnEquity: N/A
# returnOnAssets: -0.16885831553581476
# debtToEquity: N/A
# profitMargins: -0.64744
# operatingMargins: -0.08407
# grossMargins: 0.43979
# ebitdaMargins: 0.27336
# bookValue: -13.693
# priceToBook: -0.52216464
# revenueGrowth: 0.04
# earningsGrowth: N/A
# trailingPegRatio: None
# enterpriseValue: 2870091448320
# totalDebt: 2501666930688
# totalRevenue: 430800011264
# revenuePerShare: 6.866
#
# Computed ROE: N/A
# Computed ROA: -16.89%
# Fundamental Score: 6.35/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 7.15
# 50-Day MA: 8.33
# 200-Day MA: 11.03
# RSI (14): 45.36
# MACD: -0.28
# MACD Signal: -0.33
# Bollinger Bands Score: 10.00
# ATR (14): 0.37
# Volume MA (20): 398987484.25
# Stochastic %K: 23.93
# Stochastic %D: 42.74
#
# Technical Score: 7.60/10
#
# Composite Financial Strength Score: 6.85/10
# ============================================================
#
# === Jindal Stainless Limited (JSL.NS) ===
# Fundamental Metrics:
# longName: Jindal Stainless Limited
# sector: Basic Materials
# industry: Steel
# marketCap: 484303306752
# trailingPE: 20.052847
# forwardPE: 10.8334875
# dividendYield: 0.51
# dividendRate: 3.0
# fiftyTwoWeekHigh: 848.0
# fiftyTwoWeekLow: 568.05
# returnOnEquity: N/A
# returnOnAssets: 0.08804192457146566
# debtToEquity: 41.807
# profitMargins: 0.06262
# operatingMargins: 0.09749
# grossMargins: 0.30464
# ebitdaMargins: 0.115229994
# bookValue: 187.67
# priceToBook: 3.1339588
# revenueGrowth: 0.085
# earningsGrowth: -0.055
# trailingPegRatio: None
# enterpriseValue: 530831769600
# totalDebt: 64730800128
# totalRevenue: 385679097856
# revenuePerShare: 468.413
#
# Computed ROE: N/A
# Computed ROA: 8.80%
# Fundamental Score: 6.29/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 588.15
# 50-Day MA: 622.05
# 200-Day MA: 706.24
# RSI (14): 48.37
# MACD: -1.42
# MACD Signal: 2.41
# Bollinger Bands Score: 10.00
# ATR (14): 25.29
# Volume MA (20): 1039681.15
# Stochastic %K: 6.87
# Stochastic %D: 26.60
#
# Technical Score: 6.40/10
#
# Composite Financial Strength Score: 6.33/10
# ============================================================
#
# Results saved to composite_scores.xlsx

# %%
import yfinance as yf
import pandas as pd

# Assume transformed_stocks is already defined from your previous code
# transformed_stocks = [stock.split(":")[1].upper() + ".NS" for stock in stocks]

sector_data = []
for symbol in transformed_stocks:
    try:
        stock = yf.Ticker(symbol)
        info = stock.info
        # Extract the 'sector' attribute; default to 'N/A' if not found.
        sector = info.get('sector', 'N/A')
        sector_data.append({'Stock': symbol, 'Sector': sector})
    except Exception as e:
        # In case of error, store the error message
        sector_data.append({'Stock': symbol, 'Sector': f"Error: {e}"})

# Create a DataFrame with the sector info
df_sectors = pd.DataFrame(sector_data)
print(df_sectors)

# Optionally, save the sector data to an Excel file:
output_file = "stock_sectors.xlsx"
df_sectors.to_excel(output_file, index=False)
print(f"Sector information saved to {output_file}")
# Out:
#              Stock                  Sector
# 0         IREDA.NS      Financial Services
# 1           HAL.NS             Industrials
# 2     KOTAKBANK.NS      Financial Services
# 3     POLICYBZR.NS      Financial Services
# 4      TITAGARH.NS             Industrials
# 5      KPITTECH.NS              Technology
# 6      JUBLFOOD.NS       Consumer Cyclical
# 7    FEDERALBNK.NS      Financial Services
# 8          NTPC.NS               Utilities
# 9           PFC.NS      Financial Services
# 10        CANBK.NS      Financial Services
# 11         OFSS.NS              Technology
# 12      RBLBANK.NS      Financial Services
# 13   CUMMINSIND.NS             Industrials
# 14    UNIONBANK.NS      Financial Services
# 15   KALYANKJIL.NS       Consumer Cyclical
# 16        DIXON.NS              Technology
# 17       CONCOR.NS             Industrials
# 18   CHAMBLFERT.NS         Basic Materials
# 19   POONAWALLA.NS      Financial Services
# 20         SBIN.NS      Financial Services
# 21       RECLTD.NS      Financial Services
# 22      ICICIGI.NS      Financial Services
# 23   BANKBARODA.NS      Financial Services
# 24         GAIL.NS               Utilities
# 25        TECHM.NS              Technology
# 26   HINDCOPPER.NS         Basic Materials
# 27          IEX.NS      Financial Services
# 28        HUDCO.NS      Financial Services
# 29    POWERGRID.NS               Utilities
# 30     BOSCHLTD.NS       Consumer Cyclical
# 31    TATAELXSI.NS              Technology
# 32        LODHA.NS             Real Estate
# 33          PNB.NS      Financial Services
# 34         NMDC.NS         Basic Materials
# 35   IDFCFIRSTB.NS      Financial Services
# 36    JSWENERGY.NS               Utilities
# 37   PERSISTENT.NS              Technology
# 38          IGL.NS               Utilities
# 39       NAUKRI.NS  Communication Services
# 40   ICICIPRULI.NS      Financial Services
# 41   MANAPPURAM.NS      Financial Services
# 42      HDFCAMC.NS      Financial Services
# 43          PEL.NS      Financial Services
# 44         BHEL.NS             Industrials
# 45     AXISBANK.NS      Financial Services
# 46         HFCL.NS              Technology
# 47   BAJAJFINSV.NS      Financial Services
# 48         IRFC.NS      Financial Services
# 49      HCLTECH.NS              Technology
# 50      PAGEIND.NS       Consumer Cyclical
# 51   BERGEPAINT.NS         Basic Materials
# 52          LTF.NS      Financial Services
# 53    EICHERMOT.NS       Consumer Cyclical
# 54         LTIM.NS              Technology
# 55   SUPREMEIND.NS             Industrials
# 56      MPHASIS.NS              Technology
# 57          BEL.NS             Industrials
# 58   GODREJPROP.NS             Real Estate
# 59   TORNTPOWER.NS               Utilities
# 60     INDHOTEL.NS       Consumer Cyclical
# 61    SOLARINDS.NS         Basic Materials
# 62     EXIDEIND.NS       Consumer Cyclical
# 63    MOTHERSON.NS       Consumer Cyclical
# 64     RELIANCE.NS                  Energy
# 65         CESC.NS               Utilities
# 66    PATANJALI.NS      Consumer Defensive
# 67     DIVISLAB.NS              Healthcare
# 68   BAJFINANCE.NS      Financial Services
# 69         NBCC.NS             Industrials
# 70           LT.NS             Industrials
# 71   LAURUSLABS.NS              Healthcare
# 72        WIPRO.NS              Technology
# 73        PAYTM.NS              Technology
# 74     TATATECH.NS              Technology
# 75       ASTRAL.NS             Industrials
# 76         SJVN.NS               Utilities
# 77       GRASIM.NS         Basic Materials
# 78          MRF.NS       Consumer Cyclical
# 79   BHARATFORG.NS       Consumer Cyclical
# 80    BANKINDIA.NS      Financial Services
# 81         SAIL.NS         Basic Materials
# 82     HDFCBANK.NS      Financial Services
# 83   APOLLOTYRE.NS       Consumer Cyclical
# 84   BANDHANBNK.NS      Financial Services
# 85          IOC.NS                  Energy
# 86     ANGELONE.NS      Financial Services
# 87       MARUTI.NS       Consumer Cyclical
# 88    DEEPAKNTR.NS         Basic Materials
# 89        BSOFT.NS              Technology
# 90    APLAPOLLO.NS         Basic Materials
# 91         CDSL.NS      Financial Services
# 92     SHREECEM.NS         Basic Materials
# 93       JIOFIN.NS      Financial Services
# 94          NCC.NS             Industrials
# 95         MFSL.NS      Financial Services
# 96      SBILIFE.NS      Financial Services
# 97       BIOCON.NS              Healthcare
# 98      YESBANK.NS      Financial Services
# 99   TORNTPHARM.NS              Healthcare
# 100  TATAMOTORS.NS       Consumer Cyclical
# 101       ALKEM.NS              Healthcare
# 102         DLF.NS             Real Estate
# 103         TCS.NS              Technology
# 104   HINDPETRO.NS                  Energy
# 105         ABB.NS             Industrials
# 106      VOLTAS.NS       Consumer Cyclical
# 107     ESCORTS.NS             Industrials
# 108  OBEROIRLTY.NS             Real Estate
# 109      AUBANK.NS      Financial Services
# 110         ITC.NS      Consumer Defensive
# 111    TVSMOTOR.NS       Consumer Cyclical
# 112        NHPC.NS               Utilities
# 113        LICI.NS      Financial Services
# 114   LICHSGFIN.NS      Financial Services
# 115         OIL.NS                  Energy
# 116   ICICIBANK.NS      Financial Services
# 117        VEDL.NS         Basic Materials
# 118      COLPAL.NS      Consumer Defensive
# 119       PIIND.NS         Basic Materials
# 120  ADANIPORTS.NS             Industrials
# 121   TATAPOWER.NS               Utilities
# 122    PETRONET.NS                  Energy
# 123  ASIANPAINT.NS         Basic Materials
# 124  TATACONSUM.NS      Consumer Defensive
# 125  PHOENIXLTD.NS             Real Estate
# 126   AMBUJACEM.NS         Basic Materials
# 127         ACC.NS         Basic Materials
# 128  JINDALSTEL.NS         Basic Materials
# 129    HINDALCO.NS         Basic Materials
# 130     DRREDDY.NS              Healthcare
# 131  NATIONALUM.NS         Basic Materials
# 132    ASHOKLEY.NS             Industrials
# 133    GRANULES.NS              Healthcare
# 134  AUROPHARMA.NS              Healthcare
# 135  SHRIRAMFIN.NS      Financial Services
# 136         MGL.NS               Utilities
# 137  BAJAJ-AUTO.NS       Consumer Cyclical
# 138   TATASTEEL.NS         Basic Materials
# 139  GMRAIRPORT.NS             Industrials
# 140  ULTRACEMCO.NS         Basic Materials
# 141     POLYCAB.NS             Industrials
# 142       IRCTC.NS             Industrials
# 143    TATACHEM.NS         Basic Materials
# 144         IRB.NS             Industrials
# 145    RAMCOCEM.NS         Basic Materials
# 146         M&M.NS       Consumer Cyclical
# 147       ABFRL.NS       Consumer Cyclical
# 148        ONGC.NS                  Energy
# 149     SYNGENE.NS              Healthcare
# 150   ZYDUSLIFE.NS              Healthcare
# 151  HINDUNILVR.NS      Consumer Defensive
# 152     SIEMENS.NS             Industrials
# 153       NYKAA.NS       Consumer Cyclical
# 154       DMART.NS      Consumer Defensive
# 155      MARICO.NS      Consumer Defensive
# 156      CYIENT.NS             Industrials
# 157     COFORGE.NS              Technology
# 158    AARTIIND.NS         Basic Materials
# 159        BPCL.NS                  Energy
# 160    ADANIENT.NS                  Energy
# 161       LUPIN.NS              Healthcare
# 162    JSWSTEEL.NS         Basic Materials
# 163     HAVELLS.NS             Industrials
# 164   COALINDIA.NS                  Energy
# 165    TATACOMM.NS  Communication Services
# 166       DABUR.NS      Consumer Defensive
# 167  APOLLOHOSP.NS              Healthcare
# 168    UNITDSPR.NS      Consumer Defensive
# 169  INDUSTOWER.NS  Communication Services
# 170    HDFCLIFE.NS      Financial Services
# 171  BALKRISIND.NS       Consumer Cyclical
# 172   SUNPHARMA.NS              Healthcare
# 173        INFY.NS              Technology
# 174       CIPLA.NS              Healthcare
# 175     INDIANB.NS      Financial Services
# 176         UPL.NS         Basic Materials
# 177  HEROMOTOCO.NS       Consumer Cyclical
# 178        CAMS.NS              Technology
# 179  PIDILITIND.NS         Basic Materials
# 180  ADANIGREEN.NS               Utilities
# 181   DALBHARAT.NS         Basic Materials
# 182  MUTHOOTFIN.NS      Financial Services
# 183    CROMPTON.NS       Consumer Cyclical
# 184   NESTLEIND.NS      Consumer Defensive
# 185         KEI.NS             Industrials
# 186     SBICARD.NS      Financial Services
# 187   BRITANNIA.NS      Consumer Defensive
# 188  BHARTIARTL.NS  Communication Services
# 189    PRESTIGE.NS             Real Estate
# 190   ABCAPITAL.NS      Financial Services
# 191    GODREJCP.NS      Consumer Defensive
# 192    CHOLAFIN.NS      Financial Services
# 193     TIINDIA.NS             Industrials
# 194        IIFL.NS      Financial Services
# 195        ATGL.NS               Utilities
# 196         SRF.NS             Industrials
# 197         VBL.NS      Consumer Defensive
# 198         MCX.NS      Financial Services
# 199     CGPOWER.NS             Industrials
# 200  ADANIENSOL.NS               Utilities
# 201   DELHIVERY.NS             Industrials
# 202    SONACOMS.NS       Consumer Cyclical
# 203      INDIGO.NS             Industrials
# 204    GLENMARK.NS              Healthcare
# 205    JKCEMENT.NS         Basic Materials
# 206       TRENT.NS       Consumer Cyclical
# 207        LTTS.NS              Technology
# 208   MAXHEALTH.NS              Healthcare
# 209      ZOMATO.NS       Consumer Cyclical
# 210  INDUSINDBK.NS      Financial Services
# 211         BSE.NS      Financial Services
# 212       TITAN.NS       Consumer Cyclical
# 213        IDEA.NS  Communication Services
# 214         JSL.NS         Basic Materials
# Sector information saved to stock_sectors.xlsx

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import time
import random

# --------------------------
# Stock List Transformation
# --------------------------
# Original list of stocks in the format NSE:{stockname}
stocks = [
    "NSE:IREDA", "NSE:HAL", "NSE:KOTAKBANK", "NSE:POLICYBZR", "NSE:TITAGARH", "NSE:KPITTECH", "NSE:JUBLFOOD",
    "NSE:FEDERALBNK", "NSE:NTPC", "NSE:PFC", "NSE:CANBK", "NSE:OFSS", "NSE:RBLBANK", "NSE:CUMMINSIND",
    "NSE:UNIONBANK", "NSE:KALYANKJIL", "NSE:DIXON", "NSE:CONCOR", "NSE:CHAMBLFERT", "NSE:POONAWALLA",
    "NSE:SBIN", "NSE:RECLTD", "NSE:ICICIGI", "NSE:BANKBARODA", "NSE:GAIL", "NSE:TECHM", "NSE:HINDCOPPER",
    "NSE:IEX", "NSE:HUDCO", "NSE:POWERGRID", "NSE:BOSCHLTD", "NSE:TATAELXSI", "NSE:LODHA", "NSE:PNB",
    "NSE:NMDC", "NSE:IDFCFIRSTB", "NSE:JSWENERGY", "NSE:PERSISTENT", "NSE:IGL", "NSE:NAUKRI", "NSE:ICICIPRULI",
    "NSE:MANAPPURAM", "NSE:HDFCAMC", "NSE:PEL", "NSE:BHEL", "NSE:AXISBANK", "NSE:HFCL", "NSE:BAJAJFINSV",
    "NSE:IRFC", "NSE:HCLTECH", "NSE:PAGEIND", "NSE:BERGEPAINT", "NSE:LTF", "NSE:EICHERMOT", "NSE:LTIM",
    "NSE:SUPREMEIND", "NSE:MPHASIS", "NSE:BEL", "NSE:GODREJPROP", "NSE:TORNTPOWER", "NSE:INDHOTEL",
    "NSE:SOLARINDS", "NSE:EXIDEIND", "NSE:MOTHERSON", "NSE:RELIANCE", "NSE:CESC", "NSE:PATANJALI",
    "NSE:DIVISLAB", "NSE:BAJFINANCE", "NSE:NBCC", "NSE:LT", "NSE:LAURUSLABS", "NSE:WIPRO", "NSE:PAYTM",
    "NSE:TATATECH", "NSE:ASTRAL", "NSE:SJVN", "NSE:GRASIM", "NSE:MRF", "NSE:BHARATFORG", "NSE:BANKINDIA",
    "NSE:SAIL", "NSE:HDFCBANK", "NSE:APOLLOTYRE", "NSE:BANDHANBNK", "NSE:IOC", "NSE:ANGELONE", "NSE:MARUTI",
    "NSE:DEEPAKNTR", "NSE:BSOFT", "NSE:APLAPOLLO", "NSE:CDSL", "NSE:SHREECEM", "NSE:JIOFIN", "NSE:NCC",
    "NSE:MFSL", "NSE:SBILIFE", "NSE:BIOCON", "NSE:YESBANK", "NSE:TORNTPHARM", "NSE:TATAMOTORS", "NSE:ALKEM",
    "NSE:DLF", "NSE:TCS", "NSE:HINDPETRO", "NSE:ABB", "NSE:VOLTAS", "NSE:ESCORTS", "NSE:OBEROIRLTY",
    "NSE:AUBANK", "NSE:ITC", "NSE:TVSMOTOR", "NSE:NHPC", "NSE:LICI", "NSE:LICHSGFIN", "NSE:OIL",
    "NSE:ICICIBANK", "NSE:VEDL", "NSE:COLPAL", "NSE:PIIND", "NSE:ADANIPORTS", "NSE:TATAPOWER",
    "NSE:PETRONET", "NSE:ASIANPAINT", "NSE:TATACONSUM", "NSE:PHOENIXLTD", "NSE:AMBUJACEM", "NSE:ACC",
    "NSE:JINDALSTEL", "NSE:HINDALCO", "NSE:DRREDDY", "NSE:NATIONALUM", "NSE:ASHOKLEY", "NSE:GRANULES",
    "NSE:AUROPHARMA", "NSE:SHRIRAMFIN", "NSE:MGL", "NSE:BAJAJ-AUTO", "NSE:TATASTEEL", "NSE:GMRAIRPORT",
    "NSE:ULTRACEMCO", "NSE:POLYCAB", "NSE:IRCTC", "NSE:TATACHEM", "NSE:IRB", "NSE:RAMCOCEM", "NSE:M&M",
    "NSE:ABFRL", "NSE:ONGC", "NSE:SYNGENE", "NSE:ZYDUSLIFE", "NSE:HINDUNILVR", "NSE:SIEMENS", "NSE:NYKAA",
    "NSE:DMART", "NSE:MARICO", "NSE:CYIENT", "NSE:COFORGE", "NSE:AARTIIND", "NSE:BPCL", "NSE:ADANIENT",
    "NSE:LUPIN", "NSE:JSWSTEEL", "NSE:HAVELLS", "NSE:COALINDIA", "NSE:TATACOMM", "NSE:DABUR",
    "NSE:APOLLOHOSP", "NSE:UNITDSPR", "NSE:INDUSTOWER", "NSE:HDFCLIFE", "NSE:BALKRISIND", "NSE:SUNPHARMA",
    "NSE:INFY", "NSE:CIPLA", "NSE:INDIANB", "NSE:UPL", "NSE:HEROMOTOCO", "NSE:CAMS", "NSE:PIDILITIND",
    "NSE:ADANIGREEN", "NSE:DALBHARAT", "NSE:MUTHOOTFIN", "NSE:CROMPTON", "NSE:NESTLEIND", "NSE:KEI",
    "NSE:SBICARD", "NSE:BRITANNIA", "NSE:BHARTIARTL", "NSE:PRESTIGE", "NSE:ABCAPITAL", "NSE:GODREJCP",
    "NSE:CHOLAFIN", "NSE:TIINDIA", "NSE:IIFL", "NSE:ATGL", "NSE:SRF", "NSE:VBL", "NSE:MCX", "NSE:CGPOWER",
    "NSE:ADANIENSOL", "NSE:DELHIVERY", "NSE:SONACOMS", "NSE:INDIGO", "NSE:GLENMARK", "NSE:JKCEMENT",
    "NSE:TRENT", "NSE:LTTS", "NSE:MAXHEALTH", "NSE:ZOMATO", "NSE:INDUSINDBK", "NSE:BSE", "NSE:TITAN",
    "NSE:IDEA", "NSE:JSL"
]

# Transform into the required format: {STOCKNAME}.NS
transformed_stocks = [stock.split(":")[1].upper() + ".NS" for stock in stocks]

# --------------------------
# Configuration
# --------------------------
FUND_WEIGHT = 0.6  # Weight for fundamentals (optimize via backtesting if desired)
TECH_WEIGHT = 0.4  # Weight for technicals (optimize via backtesting if desired)
DISPLAY_FULL_INFO = True  # Set to True to print additional raw info for missing keys

# --------------------------
# Curated Fundamental Attributes (for printing)
# --------------------------
curated_fundamental_keys = [
    'longName', 'sector', 'industry', 'marketCap', 'trailingPE', 'forwardPE',
    'dividendYield', 'dividendRate', 'fiftyTwoWeekHigh', 'fiftyTwoWeekLow',
    'returnOnEquity', 'returnOnAssets', 'debtToEquity', 'profitMargins',
    'operatingMargins', 'grossMargins', 'ebitdaMargins', 'bookValue', 'priceToBook',
    'revenueGrowth', 'earningsGrowth', 'pegRatio', 'enterpriseValue',
    'totalDebt', 'totalRevenue', 'freeCashflow'
]

# --------------------------
# Fundamental Scoring Functions
# --------------------------
def score_pe(pe):
    if pe is None:
        return 5
    if pe < 15:
        return 10
    elif pe < 25:
        return 7
    elif pe < 40:
        return 5
    else:
        return 3

def score_roe(roe):
    if roe is None:
        return 5
    if roe > 0.20:
        return 10
    elif roe > 0.15:
        return 8
    elif roe > 0.10:
        return 6
    else:
        return 4

def score_roa(roa):
    if roa is None:
        return 5
    if roa > 0.10:
        return 10
    elif roa > 0.05:
        return 6
    else:
        return 4

def score_debt(debt):
    if debt is None:
        return 5
    if debt < 0.5:
        return 10
    elif debt < 1:
        return 7
    else:
        return 4

def score_profit_margin(pm):
    if pm is None:
        return 5
    if pm > 0.20:
        return 10
    elif pm > 0.10:
        return 7
    else:
        return 4

def score_operating_margin(om):
    if om is None:
        return 5
    if om > 0.20:
        return 10
    elif om > 0.10:
        return 7
    else:
        return 4

def score_price_to_book(pb):
    if pb is None:
        return 5
    if pb < 3:
        return 10
    elif pb < 5:
        return 7
    else:
        return 4

def score_price_to_sales(ps):
    if ps is None:
        return 5
    if ps < 2:
        return 10
    elif ps < 4:
        return 7
    else:
        return 4

def score_beta(beta):
    if beta is None:
        return 5
    if beta < 1:
        return 10
    elif beta < 1.5:
        return 7
    else:
        return 4

def score_peg(peg):
    if peg is None:
        return 5
    if peg < 1:
        return 10
    elif peg < 1.5:
        return 8
    elif peg < 2:
        return 6
    else:
        return 4

def score_ev_ebitda(ev, ebitda):
    if ev is None or ebitda is None or ebitda <= 0:
        return 5
    ratio = ev / ebitda
    if ratio < 10:
        return 10
    elif ratio < 15:
        return 8
    elif ratio < 20:
        return 6
    else:
        return 4

def score_revenue_growth(rg):
    if rg is None:
        return 5
    if rg > 0.15:
        return 10
    elif rg > 0.10:
        return 8
    elif rg > 0:
        return 6
    else:
        return 4

def score_dividend_yield(dy):
    if dy is None:
        return 5
    # Assuming dividend yield is in decimal (e.g., 0.03 for 3%)
    if 0.02 <= dy <= 0.05:
        return 10
    elif dy > 0.05:
        return 7
    else:
        return 4

def score_earnings_growth(eg):
    if eg is None:
        return 5
    if eg > 0.20:
        return 10
    elif eg > 0.10:
        return 8
    elif eg > 0:
        return 6
    else:
        return 4

def score_free_cashflow_margin(fcf, revenue):
    if fcf is None or revenue is None or revenue == 0:
        return 5
    margin = fcf / revenue
    if margin > 0.15:
        return 10
    elif margin > 0.10:
        return 8
    elif margin > 0.05:
        return 6
    else:
        return 4

# Define weights for each fundamental metric
fundamental_metric_weights = {
    'trailingPE': (score_pe, 1.0),
    'returnOnEquity': (score_roe, 2.0),
    'returnOnAssets': (score_roa, 1.5),
    'debtToEquity': (score_debt, 1.0),
    'profitMargins': (score_profit_margin, 1.0),
    'operatingMargins': (score_operating_margin, 1.0),
    'priceToBook': (score_price_to_book, 1.0),
    'priceToSalesTrailing12Months': (score_price_to_sales, 1.0),
    'beta': (score_beta, 1.0),
    'pegRatio': (score_peg, 1.0),
    'enterpriseValue_ebitda': (score_ev_ebitda, 1.0),
    'revenueGrowth': (score_revenue_growth, 1.0),
    'dividendYield': (score_dividend_yield, 1.0),
    'earningsGrowth': (score_earnings_growth, 1.0)
}

def compute_weighted_fundamental_score(info):
    total_weight = 0
    weighted_sum = 0
    # Process EV/EBITDA first if available
    if info.get('enterpriseValue') is not None and info.get('ebitda') is not None:
        score_val = score_ev_ebitda(info['enterpriseValue'], info['ebitda'])
        weight = fundamental_metric_weights['enterpriseValue_ebitda'][1]
        weighted_sum += score_val * weight
        total_weight += weight
    # Process remaining metrics from the dictionary
    for key, (score_func, weight) in fundamental_metric_weights.items():
        if key == 'enterpriseValue_ebitda':
            continue
        value = info.get(key)
        if value is not None:
            weighted_sum += score_func(value) * weight
            total_weight += weight
    # Process free cash flow margin separately if available
    if info.get('freeCashflow') is not None and info.get('totalRevenue') is not None:
        score_val = score_free_cashflow_margin(info['freeCashflow'], info['totalRevenue'])
        weight = 1.0  # Adjust weight if desired
        weighted_sum += score_val * weight
        total_weight += weight
    if total_weight == 0:
        return 5
    return weighted_sum / total_weight

# --------------------------
# Technical Indicator Functions
# --------------------------
def compute_RSI(series, period=14):
    delta = series.diff()
    gain = delta.clip(lower=0)
    loss = -delta.clip(upper=0)
    avg_gain = gain.rolling(window=period, min_periods=period).mean()
    avg_loss = loss.rolling(window=period, min_periods=period).mean()
    rs = avg_gain / avg_loss
    rsi = 100 - (100 / (1 + rs))
    return rsi

def compute_MACD(series, fast=12, slow=26, signal=9):
    ema_fast = series.ewm(span=fast, adjust=False).mean()
    ema_slow = series.ewm(span=slow, adjust=False).mean()
    macd = ema_fast - ema_slow
    macd_signal = macd.ewm(span=signal, adjust=False).mean()
    macd_hist = macd - macd_signal
    return macd, macd_signal, macd_hist

def compute_bollinger_bands(series, window=20, num_std=2):
    ma = series.rolling(window=window).mean()
    std = series.rolling(window=window).std()
    upper = ma + num_std * std
    lower = ma - num_std * std
    return lower, ma, upper

def compute_ATR(high, low, close, period=14):
    tr1 = high - low
    tr2 = (high - close.shift(1)).abs()
    tr3 = (low - close.shift(1)).abs()
    true_range = pd.concat([tr1, tr2, tr3], axis=1).max(axis=1)
    atr = true_range.rolling(window=period).mean()
    return atr

def compute_volume_MA(volume, period=20):
    return volume.rolling(window=period).mean()

def compute_stochastic(high, low, close, period=14, smooth_d=3):
    lowest_low = low.rolling(window=period).min()
    highest_high = high.rolling(window=period).max()
    k = 100 * (close - lowest_low) / (highest_high - lowest_low)
    d = k.rolling(window=smooth_d).mean()
    return k, d

def compute_ROC(series, period=12):
    # Rate of Change: percentage change over the given period
    return series.pct_change(period).iloc[-1]

def score_bollinger(last_close, lower, middle, upper):
    if lower is None or middle is None or upper is None:
        return 5
    threshold = 0.1 * middle  # within 10% of the middle is optimal
    distance = abs(last_close - middle)
    if distance <= threshold:
        return 10
    elif last_close < lower or last_close > upper:
        return 4
    else:
        return 7

def score_ROC(roc):
    if np.isnan(roc):
        return 5
    if roc > 0.05:
        return 10
    elif roc > 0:
        return 7
    else:
        return 4

def score_technicals(last_close, ma50, ma200, rsi, macd, macd_signal, bb_score, last_volume, vol_ma20, roc):
    tech_scores = []
    # 1. Price relative to MAs
    if last_close > ma50 and last_close > ma200:
        tech_scores.append(10)
    elif last_close < ma50 and last_close < ma200:
        tech_scores.append(4)
    else:
        tech_scores.append(7)
    # 2. MA Crossover signal (Golden Cross vs Death Cross)
    tech_scores.append(10 if ma50 > ma200 else 4)
    # 3. RSI scoring: 40-60 is optimal
    if 40 <= rsi <= 60:
        tech_scores.append(10)
    elif rsi < 30 or rsi > 70:
        tech_scores.append(4)
    else:
        tech_scores.append(7)
    # 4. MACD vs. Signal line
    tech_scores.append(10 if macd > macd_signal else 4)
    # 5. Bollinger Bands score
    tech_scores.append(bb_score)
    # 6. Volume signal: current volume compared to its 20-day MA
    tech_scores.append(10 if last_volume > vol_ma20 else 4)
    # 7. Rate of Change (ROC) score
    tech_scores.append(score_ROC(roc))
    return np.mean(tech_scores)

# --------------------------
# Functions to Compute Missing Fundamental Metrics
# --------------------------
def compute_ROE(stock):
    """
    Compute ROE = (Net Income - Preferred Dividends) / Total Equity.
    Tries annual data first; if not available, falls back to quarterly data.
    """
    try:
        fin = stock.financials
        bs = stock.balance_sheet
        if fin.empty:
            fin = stock.quarterly_financials
        if bs.empty:
            bs = stock.quarterly_balance_sheet
        if fin.empty or bs.empty:
            return None
        net_income_keys = ['Net Income', 'Net Income Common Stock']
        net_income = None
        for key in net_income_keys:
            if key in fin.index:
                net_income = fin.loc[key].iloc[0]
                break
        if net_income is None:
            return None
        pref_div = fin.loc['Preferred Dividends'].iloc[0] if 'Preferred Dividends' in fin.index else 0
        equity_keys = ['Total Stockholder Equity', 'Total Equity', "Total Shareholders' Equity"]
        equity = None
        for key in equity_keys:
            if key in bs.index:
                equity = bs.loc[key].iloc[0]
                break
        if equity is None or equity == 0:
            return None
        return (net_income - pref_div) / equity
    except Exception:
        return None

def compute_ROA(stock):
    """
    Compute ROA = Net Income / Total Assets.
    Tries annual data first; if not available, falls back to quarterly data.
    """
    try:
        fin = stock.financials
        bs = stock.balance_sheet
        if fin.empty:
            fin = stock.quarterly_financials
        if bs.empty:
            bs = stock.quarterly_balance_sheet
        if fin.empty or bs.empty:
            return None
        net_income_keys = ['Net Income', 'Net Income Common Stock']
        net_income = None
        for key in net_income_keys:
            if key in fin.index:
                net_income = fin.loc[key].iloc[0]
                break
        if net_income is None:
            return None
        total_assets_keys = ['Total Assets']
        total_assets = None
        for key in total_assets_keys:
            if key in bs.index:
                total_assets = bs.loc[key].iloc[0]
                break
        if total_assets is None or total_assets == 0:
            return None
        return net_income / total_assets
    except Exception:
        return None

def compute_peg_ratio(info):
    """
    Compute PEG Ratio manually as: trailingPE / (earningsGrowth * 100).
    (Assumes earningsGrowth is provided as a decimal.)
    """
    try:
        pe = info.get('trailingPE')
        eg = info.get('earningsGrowth')
        if pe is not None and eg is not None and eg > 0:
            return pe / (eg * 100)
    except Exception:
        return None
    return None

# --------------------------
# Main Analysis and Excel Output
# --------------------------
results = []  # To store {"Stock Name": ..., "Composite Score": ...}

# For example purposes, we analyze the transformed stocks.
nifty_top_10 = transformed_stocks

for symbol in nifty_top_10:
    # Retry mechanism to reduce the chance of 429 errors.
    success = False
    for attempt in range(3):
        try:
            stock = yf.Ticker(symbol)
            info = stock.info
            success = True
            break
        except Exception as e:
            wait_time = 2 * (attempt + 1)
            print(f"Error processing {symbol}: {e}. Retrying in {wait_time} seconds...")
            time.sleep(wait_time)
    if not success:
        print(f"Skipping {symbol} after multiple retries.\n")
        continue

    try:
        # Compute missing fundamental metrics (ROE and ROA)
        computed_roe = compute_ROE(stock)
        computed_roa = compute_ROA(stock)
        if computed_roe is not None:
            info['returnOnEquity'] = computed_roe
        if computed_roa is not None:
            info['returnOnAssets'] = computed_roa

        # Compute PEG if missing
        if info.get('pegRatio') is None:
            computed_peg = compute_peg_ratio(info)
            if computed_peg is not None:
                info['pegRatio'] = computed_peg

        # --------------------------
        # Display Curated Fundamental Metrics (Optional)
        # --------------------------
        print(f"=== {info.get('longName', symbol)} ({symbol}) ===")
        print("Fundamental Metrics:")
        for key in curated_fundamental_keys:
            print(f"{key}: {info.get(key, 'N/A')}")
        print()
        if info.get('returnOnEquity') is not None:
            print(f"Computed ROE: {info.get('returnOnEquity'):.2%}")
        else:
            print("Computed ROE: N/A")
        if info.get('returnOnAssets') is not None:
            print(f"Computed ROA: {info.get('returnOnAssets'):.2%}")
        else:
            print("Computed ROA: N/A")
        
        fundamental_score = compute_weighted_fundamental_score(info)
        print(f"Fundamental Score: {fundamental_score:.2f}/10\n")
        
        # If key fundamentals are missing, print additional info (optional)
        missing_keys = []
        for key in ['returnOnEquity', 'pegRatio']:
            if info.get(key) is None:
                missing_keys.append(key)
        if DISPLAY_FULL_INFO and missing_keys:
            df_info = pd.DataFrame.from_dict(info, orient='index').reset_index()
            df_info.columns = ['Attribute', 'Value']
            print("Additional info for missing metrics:")
            print(df_info[df_info['Attribute'].isin(missing_keys)])
            print("\n")
        
        # --------------------------
        # Technical Analysis (using 1-year history)
        # --------------------------
        hist = stock.history(period="1y")
        if not hist.empty:
            # Calculate moving averages, RSI, MACD, Bollinger Bands, ATR, Volume MA, and Stochastic
            hist['MA50'] = hist['Close'].rolling(window=50).mean()
            hist['MA200'] = hist['Close'].rolling(window=200).mean()
            hist['RSI'] = compute_RSI(hist['Close'], period=14)
            macd_series, macd_signal_series, _ = compute_MACD(hist['Close'])
            hist['MACD'] = macd_series
            hist['MACD_Signal'] = macd_signal_series
            lower_bb, middle_bb, upper_bb = compute_bollinger_bands(hist['Close'])
            
            hist['ATR14'] = compute_ATR(hist['High'], hist['Low'], hist['Close'], period=14)
            hist['VolMA20'] = compute_volume_MA(hist['Volume'], period=20)
            stoch_k, stoch_d = compute_stochastic(hist['High'], hist['Low'], hist['Close'], period=14, smooth_d=3)
            hist['StochK'] = stoch_k
            hist['StochD'] = stoch_d
            
            # Additional technical indicator: Rate of Change (ROC)
            roc_value = compute_ROC(hist['Close'], period=12)
            
            last_close = hist['Close'].iloc[-1]
            ma50 = hist['MA50'].iloc[-1]
            ma200 = hist['MA200'].iloc[-1]
            rsi = hist['RSI'].iloc[-1]
            macd = hist['MACD'].iloc[-1]
            macd_signal = hist['MACD_Signal'].iloc[-1]
            bb_score = score_bollinger(last_close, lower_bb.iloc[-1], middle_bb.iloc[-1], upper_bb.iloc[-1])
            atr = hist['ATR14'].iloc[-1]
            vol_ma20 = hist['VolMA20'].iloc[-1]
            last_volume = hist['Volume'].iloc[-1]
            
            print(f"Technical Metrics as of {hist.index[-1].date()}:")
            print(f"Close Price: {last_close:.2f}")
            print(f"50-Day MA: {ma50:.2f}")
            print(f"200-Day MA: {ma200:.2f}")
            print(f"RSI (14): {rsi:.2f}")
            print(f"MACD: {macd:.2f}")
            print(f"MACD Signal: {macd_signal:.2f}")
            print(f"Bollinger Bands Score: {bb_score:.2f}")
            print(f"ATR (14): {atr:.2f}")
            print(f"Volume MA (20): {vol_ma20:.2f}")
            print(f"Rate of Change (12): {roc_value:.2%}")
            print()
            
            technical_score = score_technicals(last_close, ma50, ma200, rsi, macd, macd_signal, bb_score, last_volume, vol_ma20, roc_value)
            print(f"Technical Score: {technical_score:.2f}/10\n")
            
            # Composite Score (weighted average of fundamental and technical scores)
            composite_score = FUND_WEIGHT * fundamental_score + TECH_WEIGHT * technical_score
            composite_score = max(1, min(10, composite_score))
            print(f"Composite Financial Strength Score: {composite_score:.2f}/10")
            print("="*60 + "\n")
            
            # Save result for Excel output (using the longName if available)
            stock_name = info.get('longName', symbol)
            results.append({"Stock Name": stock_name, "Composite Score": composite_score})
        else:
            print("No historical data available for technical analysis.\n")
            
    except Exception as e:
        print(f"Error processing {symbol}: {e}\n")
    
    # Pause between requests to reduce the chance of hitting rate limits.
    time.sleep(random.uniform(1, 3))

# --------------------------
# Save Results to Excel
# --------------------------
df_results = pd.DataFrame(results)
output_file = "composite_scores2_finallllll.xlsx"
df_results.to_excel(output_file, index=False)
print(f"Results saved to {output_file}")
# Out:
# === Indian Renewable Energy Development Agency Limited (IREDA.NS) ===
# Fundamental Metrics:
# longName: Indian Renewable Energy Development Agency Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 456812003328
# trailingPE: 29.81579
# forwardPE: 25.946564
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 310.0
# fiftyTwoWeekLow: 135.0
# returnOnEquity: N/A
# returnOnAssets: 0.020003524225606983
# debtToEquity: 586.184
# profitMargins: 0.6898
# operatingMargins: 0.96069
# grossMargins: 1.0
# ebitdaMargins: 0.0
# bookValue: 34.672
# priceToBook: 4.9016495
# revenueGrowth: 0.212
# earningsGrowth: 0.145
# pegRatio: 2.056261379310345
# enterpriseValue: 986899218432
# totalDebt: 547270000640
# totalRevenue: 22241163264
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 2.00%
# Fundamental Score: 6.48/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 169.95
# 50-Day MA: 174.15
# 200-Day MA: 209.80
# RSI (14): 74.01
# MACD: -4.27
# MACD Signal: -8.57
# Bollinger Bands Score: 7.00
# ATR (14): 6.85
# Volume MA (20): 19417194.05
# Rate of Change (12): 13.41%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.69/10
# ============================================================
#
# === Hindustan Aeronautics Limited (HAL.NS) ===
# Fundamental Metrics:
# longName: Hindustan Aeronautics Limited
# sector: Industrials
# industry: Aerospace & Defense
# marketCap: 2683458289664
# trailingPE: 30.843647
# forwardPE: 31.33992
# dividendYield: 0.92
# dividendRate: 38.0
# fiftyTwoWeekHigh: 5674.75
# fiftyTwoWeekLow: 3046.05
# returnOnEquity: N/A
# returnOnAssets: 0.09758668844863409
# debtToEquity: 0.004
# profitMargins: 0.27133
# operatingMargins: 0.15415
# grossMargins: 0.59347
# ebitdaMargins: 0.2736
# bookValue: 466.598
# priceToBook: 8.599373
# revenueGrowth: 0.148
# earningsGrowth: 0.142
# pegRatio: 2.1720878169014086
# enterpriseValue: 2394311884800
# totalDebt: 11500000
# totalRevenue: 320498499584
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 9.76%
# Fundamental Score: 6.67/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4012.45
# 50-Day MA: 3622.18
# 200-Day MA: 4348.65
# RSI (14): 80.62
# MACD: 98.54
# MACD Signal: 4.98
# Bollinger Bands Score: 7.00
# ATR (14): 141.99
# Volume MA (20): 2007859.60
# Rate of Change (12): 17.40%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.97/10
# ============================================================
#
# === Kotak Mahindra Bank Limited (KOTAKBANK.NS) ===
# Fundamental Metrics:
# longName: Kotak Mahindra Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 4314328989696
# trailingPE: 19.400984
# forwardPE: 19.83728
# dividendYield: 0.09
# dividendRate: 2.0
# fiftyTwoWeekHigh: 2202.5
# fiftyTwoWeekLow: 1543.85
# returnOnEquity: N/A
# returnOnAssets: 0.02372540238507256
# debtToEquity: N/A
# profitMargins: 0.30782
# operatingMargins: 0.39311
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 740.965
# priceToBook: 2.9286132
# revenueGrowth: -0.098
# earningsGrowth: 0.102
# pegRatio: 1.902057254901961
# enterpriseValue: 4624935288832
# totalDebt: 770709520384
# totalRevenue: 731945697280
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 2.37%
# Fundamental Score: 7.13/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 2170.00
# 50-Day MA: 1936.74
# 200-Day MA: 1827.02
# RSI (14): 90.39
# MACD: 52.32
# MACD Signal: 30.92
# Bollinger Bands Score: 10.00
# ATR (14): 42.05
# Volume MA (20): 4872027.00
# Rate of Change (12): 12.92%
#
# Technical Score: 9.14/10
#
# Composite Financial Strength Score: 7.94/10
# ============================================================
#
# === PB Fintech Limited (POLICYBZR.NS) ===
# Fundamental Metrics:
# longName: PB Fintech Limited
# sector: Financial Services
# industry: Insurance Brokers
# marketCap: 737261387776
# trailingPE: 309.58655
# forwardPE: 96.49955
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 2246.9
# fiftyTwoWeekLow: 1101.05
# returnOnEquity: N/A
# returnOnAssets: 0.009954655636983523
# debtToEquity: 5.473
# profitMargins: 0.0533
# operatingMargins: -0.00456
# grossMargins: 0.5838
# ebitdaMargins: -0.01632
# bookValue: 134.994
# priceToBook: 11.925344
# revenueGrowth: 0.483
# earningsGrowth: 0.867
# pegRatio: 3.5707791234140713
# enterpriseValue: 702642323456
# totalDebt: 3345600000
# totalRevenue: 45589098496
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.00%
# Fundamental Score: 5.44/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1609.85
# 50-Day MA: 1584.07
# 200-Day MA: 1670.22
# RSI (14): 65.37
# MACD: -2.91
# MACD Signal: -41.05
# Bollinger Bands Score: 10.00
# ATR (14): 78.01
# Volume MA (20): 2441776.25
# Rate of Change (12): 14.44%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.24/10
# ============================================================
#
# === Titagarh Rail Systems Limited (TITAGARH.NS) ===
# Fundamental Metrics:
# longName: Titagarh Rail Systems Limited
# sector: Industrials
# industry: Railroads
# marketCap: 109429121024
# trailingPE: 37.494232
# forwardPE: 25.507025
# dividendYield: 0.1
# dividendRate: 0.8
# fiftyTwoWeekHigh: 1896.95
# fiftyTwoWeekLow: 654.55
# returnOnEquity: N/A
# returnOnAssets: 0.08896298387653646
# debtToEquity: 21.138
# profitMargins: 0.07393
# operatingMargins: 0.103879996
# grossMargins: 0.23482999
# ebitdaMargins: 0.11261
# bookValue: 174.775
# priceToBook: 4.648834
# revenueGrowth: -0.055
# earningsGrowth: -0.199
# pegRatio: N/A
# enterpriseValue: 108710797312
# totalDebt: 4976600064
# totalRevenue: 39145902080
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 8.90%
# Fundamental Score: 5.52/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 812.50
# 50-Day MA: 845.70
# 200-Day MA: 1218.00
# RSI (14): 70.43
# MACD: -16.84
# MACD Signal: -38.86
# Bollinger Bands Score: 7.00
# ATR (14): 38.10
# Volume MA (20): 2380549.90
# Rate of Change (12): 12.76%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.11/10
# ============================================================
#
# === KPIT Technologies Limited (KPITTECH.NS) ===
# Fundamental Metrics:
# longName: KPIT Technologies Limited
# sector: Technology
# industry: Software - Infrastructure
# marketCap: 364723437568
# trailingPE: 48.251884
# forwardPE: 39.271843
# dividendYield: 0.51
# dividendRate: 7.1
# fiftyTwoWeekHigh: 1928.7
# fiftyTwoWeekLow: 1142.3
# returnOnEquity: N/A
# returnOnAssets: 0.14264583377320356
# debtToEquity: 13.968
# profitMargins: 0.13481
# operatingMargins: 0.17171
# grossMargins: 0.3461
# ebitdaMargins: 0.18604
# bookValue: 92.163
# priceToBook: 14.57038
# revenueGrowth: 0.175
# earningsGrowth: 0.2
# pegRatio: 2.4125942
# enterpriseValue: 358012452864
# totalDebt: 3492450048
# totalRevenue: 56318009344
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 14.26%
# Fundamental Score: 6.44/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1342.85
# 50-Day MA: 1322.00
# 200-Day MA: 1539.92
# RSI (14): 63.30
# MACD: -1.92
# MACD Signal: -18.18
# Bollinger Bands Score: 10.00
# ATR (14): 52.68
# Volume MA (20): 916242.75
# Rate of Change (12): 1.21%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 7.01/10
# ============================================================
#
# === Jubilant FoodWorks Limited (JUBLFOOD.NS) ===
# Fundamental Metrics:
# longName: Jubilant FoodWorks Limited
# sector: Consumer Cyclical
# industry: Restaurants
# marketCap: 439386406912
# trailingPE: 115.414505
# forwardPE: 22.932396
# dividendYield: 0.18
# dividendRate: 1.2
# fiftyTwoWeekHigh: 796.75
# fiftyTwoWeekLow: 429.6
# returnOnEquity: N/A
# returnOnAssets: 0.04914580876621307
# debtToEquity: 187.405
# profitMargins: 0.048649997
# operatingMargins: 0.090299994
# grossMargins: 0.53729
# ebitdaMargins: 0.13834
# bookValue: 33.229
# priceToBook: 20.110445
# revenueGrowth: 0.561
# earningsGrowth: -0.356
# pegRatio: N/A
# enterpriseValue: 486935527424
# totalDebt: 42419441664
# totalRevenue: 76113403904
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 4.91%
# Fundamental Score: 5.12/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 668.25
# 50-Day MA: 665.44
# 200-Day MA: 639.18
# RSI (14): 69.21
# MACD: -7.29
# MACD Signal: -14.91
# Bollinger Bands Score: 10.00
# ATR (14): 21.92
# Volume MA (20): 2247070.80
# Rate of Change (12): 9.65%
#
# Technical Score: 9.57/10
#
# Composite Financial Strength Score: 6.90/10
# ============================================================
#
# === The Federal Bank Limited (FEDERALBNK.NS) ===
# Fundamental Metrics:
# longName: The Federal Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 478290542592
# trailingPE: 11.932028
# forwardPE: 16.668093
# dividendYield: 0.61
# dividendRate: 1.2
# fiftyTwoWeekHigh: 217.0
# fiftyTwoWeekLow: 148.0
# returnOnEquity: N/A
# returnOnAssets: 0.012208770645418685
# debtToEquity: N/A
# profitMargins: 0.3052
# operatingMargins: 0.39423
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 132.926
# priceToBook: 1.4658533
# revenueGrowth: 0.038
# earningsGrowth: -0.097
# pegRatio: N/A
# enterpriseValue: 576672366592
# totalDebt: 323250290688
# totalRevenue: 132330848256
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.22%
# Fundamental Score: 7.62/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 194.85
# 50-Day MA: 184.46
# 200-Day MA: 192.02
# RSI (14): 80.05
# MACD: 1.74
# MACD Signal: -0.45
# Bollinger Bands Score: 10.00
# ATR (14): 4.00
# Volume MA (20): 7041218.00
# Rate of Change (12): 7.21%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.54/10
# ============================================================
#
# === NTPC Limited (NTPC.NS) ===
# Fundamental Metrics:
# longName: NTPC Limited
# sector: Utilities
# industry: Utilities - Regulated Electric
# marketCap: 3562071916544
# trailingPE: 17.123192
# forwardPE: 15.232462
# dividendYield: 3.13
# dividendRate: 11.5
# fiftyTwoWeekHigh: 448.45
# fiftyTwoWeekLow: 292.8
# returnOnEquity: N/A
# returnOnAssets: 0.04334035538821113
# debtToEquity: 139.959
# profitMargins: 0.118240006
# operatingMargins: 0.20751
# grossMargins: 0.42384997
# ebitdaMargins: 0.28405002
# bookValue: 173.535
# priceToBook: 2.114559
# revenueGrowth: 0.052
# earningsGrowth: 0.047
# pegRatio: 3.6432323404255316
# enterpriseValue: 5945994248192
# totalDebt: 2420094795776
# totalRevenue: 1858917498880
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 4.33%
# Fundamental Score: 7.04/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 366.95
# 50-Day MA: 322.75
# 200-Day MA: 366.30
# RSI (14): 87.46
# MACD: 10.14
# MACD Signal: 5.96
# Bollinger Bands Score: 4.00
# ATR (14): 9.21
# Volume MA (20): 14059623.75
# Rate of Change (12): 8.60%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.19/10
# ============================================================
#
# === Power Finance Corporation Limited (PFC.NS) ===
# Fundamental Metrics:
# longName: Power Finance Corporation Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 1383566934016
# trailingPE: 6.2046766
# forwardPE: 7.624113
# dividendYield: 3.29
# dividendRate: 14.0
# fiftyTwoWeekHigh: 580.0
# fiftyTwoWeekLow: 357.25
# returnOnEquity: N/A
# returnOnAssets: 0.01902164815639744
# debtToEquity: 635.304
# profitMargins: 0.53849
# operatingMargins: 0.95707
# grossMargins: 0.99573
# ebitdaMargins: 0.0
# bookValue: 333.463
# priceToBook: 1.2572609
# revenueGrowth: 0.216
# earningsGrowth: 0.232
# pegRatio: 0.2674429568965517
# enterpriseValue: 10660788305920
# totalDebt: 9221964824576
# totalRevenue: 414099013632
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.90%
# Fundamental Score: 8.32/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 419.25
# 50-Day MA: 393.69
# 200-Day MA: 458.07
# RSI (14): 69.76
# MACD: 6.15
# MACD Signal: 1.59
# Bollinger Bands Score: 10.00
# ATR (14): 13.25
# Volume MA (20): 8424953.15
# Rate of Change (12): 4.26%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.79/10
# ============================================================
#
# === Canara Bank (CANBK.NS) ===
# Fundamental Metrics:
# longName: Canara Bank
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 802389753856
# trailingPE: 4.884594
# forwardPE: 4.6730056
# dividendYield: 3.53
# dividendRate: 3.22
# fiftyTwoWeekHigh: 128.9
# fiftyTwoWeekLow: 78.6
# returnOnEquity: 0.16985
# returnOnAssets: 0.00995334778814054
# debtToEquity: N/A
# profitMargins: 0.2736
# operatingMargins: 0.39765
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 114.473
# priceToBook: 0.77275866
# revenueGrowth: -0.082
# earningsGrowth: 0.113
# pegRatio: 0.43226495575221235
# enterpriseValue: 1149779443712
# totalDebt: 924928114688
# totalRevenue: 600184389632
# freeCashflow: N/A
#
# Computed ROE: 16.98%
# Computed ROA: 1.00%
# Fundamental Score: 8.22/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 88.46
# 50-Day MA: 89.32
# 200-Day MA: 102.98
# RSI (14): 65.96
# MACD: -0.32
# MACD Signal: -1.45
# Bollinger Bands Score: 10.00
# ATR (14): 2.34
# Volume MA (20): 20427596.15
# Rate of Change (12): 3.64%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.90/10
# ============================================================
#
# === Oracle Financial Services Software Limited (OFSS.NS) ===
# Fundamental Metrics:
# longName: Oracle Financial Services Software Limited
# sector: Technology
# industry: Software - Infrastructure
# marketCap: 691773440000
# trailingPE: 30.313452
# forwardPE: 30.51322
# dividendYield: 3.01
# dividendRate: 240.0
# fiftyTwoWeekHigh: 13220.0
# fiftyTwoWeekLow: 7022.55
# returnOnEquity: 0.30737
# returnOnAssets: 0.2233715633287945
# debtToEquity: 0.318
# profitMargins: 0.33897
# operatingMargins: 0.40637
# grossMargins: 0.53208
# ebitdaMargins: 0.44559
# bookValue: 882.651
# priceToBook: 9.022762
# revenueGrowth: -0.059
# earningsGrowth: -0.272
# pegRatio: N/A
# enterpriseValue: 638036541440
# totalDebt: 244000000
# totalRevenue: 67729608704
# freeCashflow: 22489114624
#
# Computed ROE: 30.74%
# Computed ROA: 22.34%
# Fundamental Score: 7.55/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 7963.95
# 50-Day MA: 8713.74
# 200-Day MA: 10559.04
# RSI (14): 58.00
# MACD: -314.77
# MACD Signal: -440.09
# Bollinger Bands Score: 10.00
# ATR (14): 285.78
# Volume MA (20): 182971.15
# Rate of Change (12): 1.78%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 7.67/10
# ============================================================
#
# === RBL Bank Limited (RBLBANK.NS) ===
# Fundamental Metrics:
# longName: RBL Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 106493796352
# trailingPE: 10.827565
# forwardPE: 8.993327
# dividendYield: 0.86
# dividendRate: 1.5
# fiftyTwoWeekHigh: 272.05
# fiftyTwoWeekLow: 146.1
# returnOnEquity: N/A
# returnOnAssets: 0.00909971565073719
# debtToEquity: N/A
# profitMargins: 0.13143
# operatingMargins: -0.12069
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 255.482
# priceToBook: 0.6857235
# revenueGrowth: -0.212
# earningsGrowth: -0.805
# pegRatio: N/A
# enterpriseValue: 126741430272
# totalDebt: 146797101056
# totalRevenue: 75665711104
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 0.91%
# Fundamental Score: 6.57/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 175.19
# 50-Day MA: 160.61
# 200-Day MA: 192.65
# RSI (14): 72.37
# MACD: 2.57
# MACD Signal: 0.55
# Bollinger Bands Score: 10.00
# ATR (14): 5.82
# Volume MA (20): 7014559.75
# Rate of Change (12): 7.82%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.74/10
# ============================================================
#
# === Cummins India Limited (CUMMINSIND.NS) ===
# Fundamental Metrics:
# longName: Cummins India Limited
# sector: Industrials
# industry: Specialty Industrial Machinery
# marketCap: 821205008384
# trailingPE: 40.90156
# forwardPE: 36.090637
# dividendYield: 1.18
# dividendRate: 36.0
# fiftyTwoWeekHigh: 4171.9
# fiftyTwoWeekLow: 2636.75
# returnOnEquity: N/A
# returnOnAssets: 0.19180403343845556
# debtToEquity: 0.403
# profitMargins: 0.19623
# operatingMargins: 0.21305999
# grossMargins: 0.35691002
# ebitdaMargins: 0.22593
# bookValue: 251.318
# priceToBook: 11.787855
# revenueGrowth: 0.218
# earningsGrowth: 0.119
# pegRatio: 3.4371058823529417
# enterpriseValue: 793321996288
# totalDebt: 281000000
# totalRevenue: 102393298944
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 19.18%
# Fundamental Score: 7.11/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 2962.50
# 50-Day MA: 2848.98
# 200-Day MA: 3422.87
# RSI (14): 56.78
# MACD: 33.79
# MACD Signal: 15.40
# Bollinger Bands Score: 10.00
# ATR (14): 97.99
# Volume MA (20): 463100.60
# Rate of Change (12): -0.36%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.07/10
# ============================================================
#
# === Union Bank of India (UNIONBANK.NS) ===
# Fundamental Metrics:
# longName: Union Bank of India
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 941682196480
# trailingPE: 5.7510486
# forwardPE: 7.0652924
# dividendYield: 2.82
# dividendRate: 3.6
# fiftyTwoWeekHigh: 172.5
# fiftyTwoWeekLow: 100.81
# returnOnEquity: 0.15843001
# returnOnAssets: 0.009841054879498936
# debtToEquity: N/A
# profitMargins: 0.32317
# operatingMargins: 0.47632998
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 147.009
# priceToBook: 0.8391323
# revenueGrowth: 0.049
# earningsGrowth: 0.239
# pegRatio: 0.24062964853556487
# enterpriseValue: 794490044416
# totalDebt: 327184908288
# totalRevenue: 505737347072
# freeCashflow: N/A
#
# Computed ROE: 15.84%
# Computed ROA: 0.98%
# Fundamental Score: 8.30/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 123.36
# 50-Day MA: 113.61
# 200-Day MA: 121.46
# RSI (14): 66.76
# MACD: 2.32
# MACD Signal: 1.16
# Bollinger Bands Score: 10.00
# ATR (14): 3.62
# Volume MA (20): 8683801.90
# Rate of Change (12): 5.53%
#
# Technical Score: 8.71/10
#
# Composite Financial Strength Score: 8.46/10
# ============================================================
#
# === Kalyan Jewellers India Limited (KALYANKJIL.NS) ===
# Fundamental Metrics:
# longName: Kalyan Jewellers India Limited
# sector: Consumer Cyclical
# industry: Luxury Goods
# marketCap: 483951673344
# trailingPE: 72.519325
# forwardPE: 42.994987
# dividendYield: 0.24
# dividendRate: 1.2
# fiftyTwoWeekHigh: 795.4
# fiftyTwoWeekLow: 336.05
# returnOnEquity: N/A
# returnOnAssets: 0.046603085490533235
# debtToEquity: 104.385
# profitMargins: 0.028380001
# operatingMargins: 0.048010003
# grossMargins: 0.13094
# ebitdaMargins: 0.05416
# bookValue: 42.388
# priceToBook: 11.069171
# revenueGrowth: 0.395
# earningsGrowth: 0.211
# pegRatio: 3.436934834123223
# enterpriseValue: 519330168832
# totalDebt: 45499129856
# totalRevenue: 234227744768
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 4.66%
# Fundamental Score: 5.70/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 469.20
# 50-Day MA: 483.59
# 200-Day MA: 597.06
# RSI (14): 52.72
# MACD: -9.79
# MACD Signal: -18.60
# Bollinger Bands Score: 10.00
# ATR (14): 23.40
# Volume MA (20): 10302511.55
# Rate of Change (12): 4.17%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.22/10
# ============================================================
#
# === Dixon Technologies (India) Limited (DIXON.NS) ===
# Fundamental Metrics:
# longName: Dixon Technologies (India) Limited
# sector: Technology
# industry: Consumer Electronics
# marketCap: 818824282112
# trailingPE: 96.15032
# forwardPE: 73.71767
# dividendYield: 0.03
# dividendRate: 5.0
# fiftyTwoWeekHigh: 19148.9
# fiftyTwoWeekLow: 7108.7
# returnOnEquity: N/A
# returnOnAssets: 0.05259996138140157
# debtToEquity: 30.83
# profitMargins: 0.02377
# operatingMargins: 0.03022
# grossMargins: 0.079239994
# ebitdaMargins: 0.03482
# bookValue: 393.424
# priceToBook: 34.630577
# revenueGrowth: 1.17
# earningsGrowth: 1.199
# pegRatio: 0.8019209341117597
# enterpriseValue: 654715453440
# totalDebt: 7939800064
# totalRevenue: 332255297536
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 5.26%
# Fundamental Score: 6.59/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 13624.50
# 50-Day MA: 14569.46
# 200-Day MA: 14215.45
# RSI (14): 44.37
# MACD: -208.54
# MACD Signal: -331.39
# Bollinger Bands Score: 10.00
# ATR (14): 592.21
# Volume MA (20): 332465.75
# Rate of Change (12): -4.43%
#
# Technical Score: 8.29/10
#
# Composite Financial Strength Score: 7.27/10
# ============================================================
#
# === Container Corporation of India Limited (CONCOR.NS) ===
# Fundamental Metrics:
# longName: Container Corporation of India Limited
# sector: Industrials
# industry: Railroads
# marketCap: 433604100096
# trailingPE: 33.13082
# forwardPE: 25.406998
# dividendYield: 2.37
# dividendRate: 17.0
# fiftyTwoWeekHigh: 1180.0
# fiftyTwoWeekLow: 601.25
# returnOnEquity: N/A
# returnOnAssets: 0.08979814845947155
# debtToEquity: 7.45
# profitMargins: 0.14609
# operatingMargins: 0.17185
# grossMargins: 0.26195
# ebitdaMargins: 0.21691
# bookValue: 199.835
# priceToBook: 3.561188
# revenueGrowth: -0.001
# earningsGrowth: 0.109
# pegRatio: 3.0395247706422017
# enterpriseValue: 404930035712
# totalDebt: 9149700096
# totalRevenue: 89472901120
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 8.98%
# Fundamental Score: 5.93/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 711.65
# 50-Day MA: 702.01
# 200-Day MA: 856.58
# RSI (14): 75.20
# MACD: -0.86
# MACD Signal: -11.65
# Bollinger Bands Score: 10.00
# ATR (14): 21.86
# Volume MA (20): 1251393.10
# Rate of Change (12): 7.18%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 6.70/10
# ============================================================
#
# === Chambal Fertilisers and Chemicals Limited (CHAMBLFERT.NS) ===
# Fundamental Metrics:
# longName: Chambal Fertilisers and Chemicals Limited
# sector: Basic Materials
# industry: Agricultural Inputs
# marketCap: 246140551168
# trailingPE: 15.187885
# forwardPE: 35.105713
# dividendYield: 1.29
# dividendRate: 8.0
# fiftyTwoWeekHigh: 622.6
# fiftyTwoWeekLow: 333.4
# returnOnEquity: N/A
# returnOnAssets: 0.11085266535580508
# debtToEquity: 1.215
# profitMargins: 0.09595
# operatingMargins: 0.14130001
# grossMargins: 0.43006
# ebitdaMargins: 0.14817001
# bookValue: 204.806
# priceToBook: 2.999668
# revenueGrowth: 0.131
# earningsGrowth: 0.208
# pegRatio: 0.7301867788461538
# enterpriseValue: 218450132992
# totalDebt: 994499968
# totalRevenue: 168405106688
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 11.09%
# Fundamental Score: 8.30/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 614.35
# 50-Day MA: 535.98
# 200-Day MA: 505.26
# RSI (14): 75.51
# MACD: 18.88
# MACD Signal: 15.37
# Bollinger Bands Score: 10.00
# ATR (14): 19.59
# Volume MA (20): 2469547.80
# Rate of Change (12): 6.49%
#
# Technical Score: 8.29/10
#
# Composite Financial Strength Score: 8.29/10
# ============================================================
#
# === Poonawalla Fincorp Limited (POONAWALLA.NS) ===
# Fundamental Metrics:
# longName: Poonawalla Fincorp Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 268361728000
# trailingPE: 161.18604
# forwardPE: 25.622921
# dividendYield: 1.3
# dividendRate: 4.0
# fiftyTwoWeekHigh: 514.0
# fiftyTwoWeekLow: 267.2
# returnOnEquity: N/A
# returnOnAssets: 0.06986162602908635
# debtToEquity: 225.886
# profitMargins: 0.13118
# operatingMargins: 0.07768
# grossMargins: 0.99857
# ebitdaMargins: 0.0
# bookValue: 103.808
# priceToBook: 3.3383746
# revenueGrowth: -0.406
# earningsGrowth: -0.93
# pegRatio: N/A
# enterpriseValue: 450143387648
# totalDebt: 181070004224
# totalRevenue: 13037899776
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 6.99%
# Fundamental Score: 5.22/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 346.55
# 50-Day MA: 302.94
# 200-Day MA: 358.11
# RSI (14): 85.87
# MACD: 9.99
# MACD Signal: 1.78
# Bollinger Bands Score: 4.00
# ATR (14): 11.73
# Volume MA (20): 2152138.00
# Rate of Change (12): 21.07%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 5.93/10
# ============================================================
#
# === State Bank of India (SBIN.NS) ===
# Fundamental Metrics:
# longName: State Bank of India
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 6897392418816
# trailingPE: 8.690543
# forwardPE: 9.348615
# dividendYield: 1.75
# dividendRate: 13.7
# fiftyTwoWeekHigh: 912.0
# fiftyTwoWeekLow: 680.0
# returnOnEquity: 0.1816
# returnOnAssets: 0.009962410125944251
# debtToEquity: N/A
# profitMargins: 0.23271999
# operatingMargins: 0.28902
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 538.053
# priceToBook: 1.4363827
# revenueGrowth: 0.059
# earningsGrowth: 0.703
# pegRatio: 0.12362081081081082
# enterpriseValue: 11115593465856
# totalDebt: 7560226144256
# totalRevenue: 3409518788608
# freeCashflow: N/A
#
# Computed ROE: 18.16%
# Computed ROA: 1.00%
# Fundamental Score: 8.30/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 772.85
# 50-Day MA: 740.77
# 200-Day MA: 801.82
# RSI (14): 77.47
# MACD: 6.77
# MACD Signal: -0.63
# Bollinger Bands Score: 10.00
# ATR (14): 12.87
# Volume MA (20): 8893371.70
# Rate of Change (12): 5.57%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 8.12/10
# ============================================================
#
# === REC Limited (RECLTD.NS) ===
# Fundamental Metrics:
# longName: REC Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 1165858177024
# trailingPE: 7.467532
# forwardPE: 6.539882
# dividendYield: 3.46
# dividendRate: 15.4
# fiftyTwoWeekHigh: 654.0
# fiftyTwoWeekLow: 357.35
# returnOnEquity: 0.21976
# returnOnAssets: 0.02580388528387063
# debtToEquity: 678.386
# profitMargins: 0.74731004
# operatingMargins: 0.94655997
# grossMargins: 0.99274004
# ebitdaMargins: 0.0
# bookValue: 293.048
# priceToBook: 1.5108446
# revenueGrowth: 0.272
# earningsGrowth: 0.232
# pegRatio: 0.3218763793103448
# enterpriseValue: 6205704503296
# totalDebt: 5234832179200
# totalRevenue: 209463197696
# freeCashflow: N/A
#
# Computed ROE: 21.98%
# Computed ROA: 2.58%
# Fundamental Score: 8.34/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 442.75
# 50-Day MA: 420.63
# 200-Day MA: 512.00
# RSI (14): 78.19
# MACD: 5.72
# MACD Signal: -1.09
# Bollinger Bands Score: 10.00
# ATR (14): 13.42
# Volume MA (20): 8261200.30
# Rate of Change (12): 7.16%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 8.15/10
# ============================================================
#
# === ICICI Lombard General Insurance Company Limited (ICICIGI.NS) ===
# Fundamental Metrics:
# longName: ICICI Lombard General Insurance Company Limited
# sector: Financial Services
# industry: Insurance - Diversified
# marketCap: 881909497856
# trailingPE: 35.34962
# forwardPE: 30.528393
# dividendYield: 0.62
# dividendRate: 11.0
# fiftyTwoWeekHigh: 2301.9
# fiftyTwoWeekLow: 1480.5
# returnOnEquity: 0.18601
# returnOnAssets: 0.03030552865908964
# debtToEquity: N/A
# profitMargins: 0.10817
# operatingMargins: 0.15652001
# grossMargins: 0.26003
# ebitdaMargins: 0.14462
# bookValue: 292.415
# priceToBook: 6.085529
# revenueGrowth: 0.193
# earningsGrowth: 0.659
# pegRatio: 0.5364130500758725
# enterpriseValue: 878226964480
# totalDebt: 0
# totalRevenue: 232810397696
# freeCashflow: N/A
#
# Computed ROE: 18.60%
# Computed ROA: 3.03%
# Fundamental Score: 7.10/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1779.50
# 50-Day MA: 1776.71
# 200-Day MA: 1907.36
# RSI (14): 72.00
# MACD: -2.10
# MACD Signal: -17.25
# Bollinger Bands Score: 10.00
# ATR (14): 46.60
# Volume MA (20): 894329.30
# Rate of Change (12): 4.54%
#
# Technical Score: 6.57/10
#
# Composite Financial Strength Score: 6.89/10
# ============================================================
#
# === Bank of Baroda Limited (BANKBARODA.NS) ===
# Fundamental Metrics:
# longName: Bank of Baroda Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 1153729167360
# trailingPE: 5.6459126
# forwardPE: 10.125737
# dividendYield: 3.39
# dividendRate: 7.6
# fiftyTwoWeekHigh: 299.7
# fiftyTwoWeekLow: 190.7
# returnOnEquity: 0.15798001
# returnOnAssets: 0.011341317806947818
# debtToEquity: N/A
# profitMargins: 0.32016
# operatingMargins: 0.43094003
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 270.34
# priceToBook: 0.82514614
# revenueGrowth: 0.06
# earningsGrowth: 0.089
# pegRatio: 0.6343722022471909
# enterpriseValue: 2036144144384
# totalDebt: 1411515940864
# totalRevenue: 638094737408
# freeCashflow: N/A
#
# Computed ROE: 15.80%
# Computed ROA: 1.13%
# Fundamental Score: 8.22/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 223.07
# 50-Day MA: 213.57
# 200-Day MA: 241.17
# RSI (14): 84.39
# MACD: 1.81
# MACD Signal: -1.16
# Bollinger Bands Score: 10.00
# ATR (14): 4.75
# Volume MA (20): 9292501.40
# Rate of Change (12): 7.68%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 8.08/10
# ============================================================
#
# === GAIL (India) Limited (GAIL.NS) ===
# Fundamental Metrics:
# longName: GAIL (India) Limited
# sector: Utilities
# industry: Utilities - Regulated Gas
# marketCap: 1168519593984
# trailingPE: 9.397144
# forwardPE: 10.533491
# dividendYield: 3.59
# dividendRate: 6.5
# fiftyTwoWeekHigh: 246.3
# fiftyTwoWeekLow: 150.52
# returnOnEquity: N/A
# returnOnAssets: 0.07937331513857387
# debtToEquity: 23.366
# profitMargins: 0.08991
# operatingMargins: 0.060539998
# grossMargins: 0.18885
# ebitdaMargins: 0.10962
# bookValue: 127.57
# priceToBook: 1.3929607
# revenueGrowth: 0.062
# earningsGrowth: 0.278
# pegRatio: 0.33802676258992803
# enterpriseValue: 1334353068032
# totalDebt: 196317691904
# totalRevenue: 1382177177600
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 7.94%
# Fundamental Score: 7.70/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 177.70
# 50-Day MA: 165.17
# 200-Day MA: 196.78
# RSI (14): 74.74
# MACD: 2.47
# MACD Signal: -0.49
# Bollinger Bands Score: 10.00
# ATR (14): 5.52
# Volume MA (20): 13621314.50
# Rate of Change (12): 10.06%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 7.77/10
# ============================================================
#
# === Tech Mahindra Limited (TECHM.NS) ===
# Fundamental Metrics:
# longName: Tech Mahindra Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 1287765229568
# trailingPE: 34.531433
# forwardPE: 22.506573
# dividendYield: 2.95
# dividendRate: 43.0
# fiftyTwoWeekHigh: 1807.7
# fiftyTwoWeekLow: 1162.95
# returnOnEquity: N/A
# returnOnAssets: 0.054297663021951194
# debtToEquity: 7.566
# profitMargins: 0.07138
# operatingMargins: 0.10163
# grossMargins: 0.3048
# ebitdaMargins: 0.11293
# bookValue: 298.711
# priceToBook: 4.8726025
# revenueGrowth: 0.014
# earningsGrowth: 0.924
# pegRatio: 0.37371680735930735
# enterpriseValue: 1251614130176
# totalDebt: 20351000576
# totalRevenue: 524755992576
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 5.43%
# Fundamental Score: 6.67/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1455.50
# 50-Day MA: 1596.36
# 200-Day MA: 1595.47
# RSI (14): 43.81
# MACD: -52.45
# MACD Signal: -55.11
# Bollinger Bands Score: 10.00
# ATR (14): 38.40
# Volume MA (20): 2269520.85
# Rate of Change (12): -3.19%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.97/10
# ============================================================
#
# === Hindustan Copper Limited (HINDCOPPER.NS) ===
# Fundamental Metrics:
# longName: Hindustan Copper Limited
# sector: Basic Materials
# industry: Copper
# marketCap: 221493035008
# trailingPE: 55.033657
# forwardPE: N/A
# dividendYield: 0.39
# dividendRate: 0.92
# fiftyTwoWeekHigh: 415.8
# fiftyTwoWeekLow: 195.4
# returnOnEquity: N/A
# returnOnAssets: 0.09030589599825961
# debtToEquity: 3.8
# profitMargins: 0.21117
# operatingMargins: 0.26159
# grossMargins: 1.02265
# ebitdaMargins: 0.38188
# bookValue: 24.899
# priceToBook: 9.194747
# revenueGrowth: -0.179
# earningsGrowth: 0.0
# pegRatio: N/A
# enterpriseValue: 220877258752
# totalDebt: 915000000
# totalRevenue: 19049261056
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 9.03%
# Fundamental Score: 5.36/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 228.94
# 50-Day MA: 226.99
# 200-Day MA: 284.12
# RSI (14): 69.62
# MACD: 1.03
# MACD Signal: -1.74
# Bollinger Bands Score: 10.00
# ATR (14): 9.65
# Volume MA (20): 5235315.25
# Rate of Change (12): 2.45%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 6.36/10
# ============================================================
#
# === Indian Energy Exchange Limited (IEX.NS) ===
# Fundamental Metrics:
# longName: Indian Energy Exchange Limited
# sector: Financial Services
# industry: Capital Markets
# marketCap: 156523577344
# trailingPE: 38.34205
# forwardPE: 39.548317
# dividendYield: 1.68
# dividendRate: 3.0
# fiftyTwoWeekHigh: 244.4
# fiftyTwoWeekLow: 133.15
# returnOnEquity: N/A
# returnOnAssets: 0.19777331606809176
# debtToEquity: 0.784
# profitMargins: 0.64668
# operatingMargins: 0.84831
# grossMargins: 0.99821
# ebitdaMargins: 0.84899
# bookValue: 11.763
# priceToBook: 14.961321
# revenueGrowth: 0.137
# earningsGrowth: 0.175
# pegRatio: 2.1909742857142858
# enterpriseValue: 145344053248
# totalDebt: 81839000
# totalRevenue: 6320589824
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 19.78%
# Fundamental Score: 7.11/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 175.99
# 50-Day MA: 167.36
# 200-Day MA: 180.88
# RSI (14): 73.73
# MACD: 1.52
# MACD Signal: -0.95
# Bollinger Bands Score: 10.00
# ATR (14): 5.23
# Volume MA (20): 5663779.60
# Rate of Change (12): 7.77%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.07/10
# ============================================================
#
# === Housing and Urban Development Corporation Limited (HUDCO.NS) ===
# Fundamental Metrics:
# longName: Housing and Urban Development Corporation Limited
# sector: Financial Services
# industry: Credit Services
# marketCap: 408447647744
# trailingPE: 15.2488785
# forwardPE: 12.365455
# dividendYield: 1.48
# dividendRate: 3.1
# fiftyTwoWeekHigh: 353.7
# fiftyTwoWeekLow: 158.85
# returnOnEquity: N/A
# returnOnAssets: 0.022657214537764737
# debtToEquity: 546.443
# profitMargins: 0.68615997
# operatingMargins: 0.90939003
# grossMargins: 0.99616
# ebitdaMargins: 0.0
# bookValue: 85.536
# priceToBook: 2.3853114
# revenueGrowth: 0.332
# earningsGrowth: 0.417
# pegRatio: 0.36568053956834534
# enterpriseValue: 1327010545664
# totalDebt: 935653212160
# totalRevenue: 39080599552
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 2.27%
# Fundamental Score: 7.60/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 204.03
# 50-Day MA: 196.99
# 200-Day MA: 238.05
# RSI (14): 80.91
# MACD: 2.76
# MACD Signal: -1.61
# Bollinger Bands Score: 7.00
# ATR (14): 7.61
# Volume MA (20): 7201285.85
# Rate of Change (12): 12.24%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.53/10
# ============================================================
#
# === Power Grid Corporation of India Limited (POWERGRID.NS) ===
# Fundamental Metrics:
# longName: Power Grid Corporation of India Limited
# sector: Utilities
# industry: Utilities - Regulated Electric
# marketCap: 2706940362752
# trailingPE: 17.466988
# forwardPE: 13.681241
# dividendYield: 5.14
# dividendRate: 15.0
# fiftyTwoWeekHigh: 366.25
# fiftyTwoWeekLow: 247.3
# returnOnEquity: N/A
# returnOnAssets: 0.062071536222253434
# debtToEquity: 137.073
# profitMargins: 0.34168
# operatingMargins: 0.56279
# grossMargins: 0.97960997
# ebitdaMargins: 0.86168
# bookValue: 99.026
# priceToBook: 2.9386222
# revenueGrowth: -0.027
# earningsGrowth: -0.042
# pegRatio: N/A
# enterpriseValue: 3880143814656
# totalDebt: 1261904592896
# totalRevenue: 454950813696
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 6.21%
# Fundamental Score: 7.12/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 291.00
# 50-Day MA: 275.19
# 200-Day MA: 310.50
# RSI (14): 84.01
# MACD: 3.82
# MACD Signal: -0.16
# Bollinger Bands Score: 10.00
# ATR (14): 7.62
# Volume MA (20): 15435918.95
# Rate of Change (12): 9.13%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 7.41/10
# ============================================================
#
# === Bosch Limited (BOSCHLTD.NS) ===
# Fundamental Metrics:
# longName: Bosch Limited
# sector: Consumer Cyclical
# industry: Auto Parts
# marketCap: 809567977472
# trailingPE: 39.946007
# forwardPE: 35.099815
# dividendYield: 1.2
# dividendRate: 340.0
# fiftyTwoWeekHigh: 39088.8
# fiftyTwoWeekLow: 26005.0
# returnOnEquity: N/A
# returnOnAssets: 0.14360319335965646
# debtToEquity: 0.247
# profitMargins: 0.11766
# operatingMargins: 0.107889995
# grossMargins: 0.34393
# ebitdaMargins: 0.13254
# bookValue: 4317.642
# priceToBook: 6.357197
# revenueGrowth: 0.062
# earningsGrowth: -0.115
# pegRatio: N/A
# enterpriseValue: 774940917760
# totalDebt: 314000000
# totalRevenue: 172166004736
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 14.36%
# Fundamental Score: 6.64/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 27448.10
# 50-Day MA: 28141.90
# 200-Day MA: 32891.51
# RSI (14): 61.76
# MACD: -165.43
# MACD Signal: -410.01
# Bollinger Bands Score: 10.00
# ATR (14): 663.27
# Volume MA (20): 24073.20
# Rate of Change (12): 1.40%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.96/10
# ============================================================
#
# === Tata Elxsi Limited (TATAELXSI.NS) ===
# Fundamental Metrics:
# longName: Tata Elxsi Limited
# sector: Technology
# industry: Software - Application
# marketCap: 342372581376
# trailingPE: 42.267975
# forwardPE: 37.367474
# dividendYield: 1.24
# dividendRate: 70.0
# fiftyTwoWeekHigh: 9080.0
# fiftyTwoWeekLow: 5157.7
# returnOnEquity: N/A
# returnOnAssets: 0.2485856523300919
# debtToEquity: 8.276
# profitMargins: 0.21654
# operatingMargins: 0.23493999
# grossMargins: 0.38589
# ebitdaMargins: 0.26397
# bookValue: 399.27
# priceToBook: 13.767502
# revenueGrowth: 0.027
# earningsGrowth: -0.036
# pegRatio: N/A
# enterpriseValue: 331279106048
# totalDebt: 2057787008
# totalRevenue: 37381812224
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 24.86%
# Fundamental Score: 6.48/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5496.95
# 50-Day MA: 5913.90
# 200-Day MA: 6840.91
# RSI (14): 54.14
# MACD: -152.63
# MACD Signal: -198.43
# Bollinger Bands Score: 10.00
# ATR (14): 164.28
# Volume MA (20): 166922.00
# Rate of Change (12): -2.51%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.86/10
# ============================================================
#
# === Macrotech Developers Limited (LODHA.NS) ===
# Fundamental Metrics:
# longName: Macrotech Developers Limited
# sector: Real Estate
# industry: Real Estate - Development
# marketCap: 1207255826432
# trailingPE: 47.799294
# forwardPE: 36.371136
# dividendYield: 0.18
# dividendRate: 2.25
# fiftyTwoWeekHigh: 1649.95
# fiftyTwoWeekLow: 1035.15
# returnOnEquity: 0.15777001
# returnOnAssets: 0.032802402107349464
# debtToEquity: 43.778
# profitMargins: 0.18478
# operatingMargins: 0.30337998
# grossMargins: 0.38598
# ebitdaMargins: 0.27271998
# bookValue: 182.749
# priceToBook: 6.6200094
# revenueGrowth: 0.393
# earningsGrowth: 0.817
# pegRatio: 0.5850586780905754
# enterpriseValue: 1259908628480
# totalDebt: 79896002560
# totalRevenue: 135736999936
# freeCashflow: N/A
#
# Computed ROE: 15.78%
# Computed ROA: 3.28%
# Fundamental Score: 6.77/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1209.80
# 50-Day MA: 1161.46
# 200-Day MA: 1279.36
# RSI (14): 60.45
# MACD: 0.30
# MACD Signal: -15.46
# Bollinger Bands Score: 10.00
# ATR (14): 55.45
# Volume MA (20): 1497309.10
# Rate of Change (12): 6.30%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.04/10
# ============================================================
#
# === Punjab National Bank (PNB.NS) ===
# Fundamental Metrics:
# longName: Punjab National Bank
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 1078374105088
# trailingPE: 6.2125826
# forwardPE: 6.676868
# dividendYield: 1.56
# dividendRate: 1.5
# fiftyTwoWeekHigh: 142.9
# fiftyTwoWeekLow: 85.46
# returnOnEquity: 0.14027001
# returnOnAssets: 0.005696856712769053
# debtToEquity: N/A
# profitMargins: 0.32672
# operatingMargins: 0.47184
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 114.203
# priceToBook: 0.821432
# revenueGrowth: 0.446
# earningsGrowth: 0.891
# pegRatio: 0.06972595510662177
# enterpriseValue: 1364369342464
# totalDebt: 901469372416
# totalRevenue: 515221585920
# freeCashflow: N/A
#
# Computed ROE: 14.03%
# Computed ROA: 0.57%
# Fundamental Score: 8.30/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 93.81
# 50-Day MA: 94.56
# 200-Day MA: 106.64
# RSI (14): 67.23
# MACD: -0.49
# MACD Signal: -1.53
# Bollinger Bands Score: 10.00
# ATR (14): 2.33
# Volume MA (20): 20044860.65
# Rate of Change (12): 3.10%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 7.95/10
# ============================================================
#
# === NMDC Limited (NMDC.NS) ===
# Fundamental Metrics:
# longName: NMDC Limited
# sector: Basic Materials
# industry: Steel
# marketCap: 599686709248
# trailingPE: 9.252375
# forwardPE: 2.644048
# dividendYield: 4.03
# dividendRate: 2.8
# fiftyTwoWeekHigh: 95.45
# fiftyTwoWeekLow: 59.7
# returnOnEquity: N/A
# returnOnAssets: 0.15633480020066723
# debtToEquity: 14.651
# profitMargins: 0.27691
# operatingMargins: 0.34552
# grossMargins: 0.53150004
# ebitdaMargins: 0.34916002
# bookValue: 32.266
# priceToBook: 2.1133702
# revenueGrowth: 0.214
# earningsGrowth: 0.269
# pegRatio: 0.34395446096654275
# enterpriseValue: 498555912192
# totalDebt: 41577299968
# totalRevenue: 233902407680
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 15.63%
# Fundamental Score: 9.11/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 68.19
# 50-Day MA: 63.16
# 200-Day MA: 70.97
# RSI (14): 73.37
# MACD: 1.27
# MACD Signal: 0.57
# Bollinger Bands Score: 10.00
# ATR (14): 2.23
# Volume MA (20): 23344267.10
# Rate of Change (12): 5.45%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 8.61/10
# ============================================================
#
# === IDFC First Bank Limited (IDFCFIRSTB.NS) ===
# Fundamental Metrics:
# longName: IDFC First Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 419900063744
# trailingPE: 21.560148
# forwardPE: 12.32321
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 86.1
# fiftyTwoWeekLow: 52.6
# returnOnEquity: 0.05869
# returnOnAssets: 0.00993333919253671
# debtToEquity: N/A
# profitMargins: 0.096920006
# operatingMargins: 0.078990005
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 51.758
# priceToBook: 1.1080413
# revenueGrowth: 0.038
# earningsGrowth: -0.553
# pegRatio: N/A
# enterpriseValue: 725278261248
# totalDebt: 463983706112
# totalRevenue: 198785548288
# freeCashflow: N/A
#
# Computed ROE: 5.87%
# Computed ROA: 0.99%
# Fundamental Score: 5.74/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 57.35
# 50-Day MA: 59.71
# 200-Day MA: 68.44
# RSI (14): 52.22
# MACD: -1.12
# MACD Signal: -1.50
# Bollinger Bands Score: 10.00
# ATR (14): 1.39
# Volume MA (20): 26372565.25
# Rate of Change (12): -0.73%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.41/10
# ============================================================
#
# === JSW Energy Limited (JSWENERGY.NS) ===
# Fundamental Metrics:
# longName: JSW Energy Limited
# sector: Utilities
# industry: Utilities - Independent Power Producers
# marketCap: 969180119040
# trailingPE: 50.5323
# forwardPE: 88.9984
# dividendYield: 0.35
# dividendRate: 2.0
# fiftyTwoWeekHigh: 804.9
# fiftyTwoWeekLow: 418.75
# returnOnEquity: N/A
# returnOnAssets: 0.029564726415887668
# debtToEquity: 109.09
# profitMargins: 0.16745001
# operatingMargins: 0.20838
# grossMargins: 0.57083
# ebitdaMargins: 0.45771
# bookValue: 160.629
# priceToBook: 3.4573457
# revenueGrowth: -0.041
# earningsGrowth: -0.319
# pegRatio: N/A
# enterpriseValue: 1216527728640
# totalDebt: 308530610176
# totalRevenue: 113118699520
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 2.96%
# Fundamental Score: 5.60/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 555.35
# 50-Day MA: 505.16
# 200-Day MA: 646.85
# RSI (14): 71.42
# MACD: 18.63
# MACD Signal: 10.44
# Bollinger Bands Score: 10.00
# ATR (14): 21.55
# Volume MA (20): 4789497.10
# Rate of Change (12): 11.16%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.16/10
# ============================================================
#
# === Persistent Systems Limited (PERSISTENT.NS) ===
# Fundamental Metrics:
# longName: Persistent Systems Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 856823037952
# trailingPE: 65.30724
# forwardPE: 100.602715
# dividendYield: 0.55
# dividendRate: 30.0
# fiftyTwoWeekHigh: 6788.9
# fiftyTwoWeekLow: 3232.05
# returnOnEquity: 0.24133
# returnOnAssets: 0.14829775559298028
# debtToEquity: 7.764
# profitMargins: 0.11659
# operatingMargins: 0.14385
# grossMargins: 0.27
# ebitdaMargins: 0.15414
# bookValue: 397.262
# priceToBook: 13.991522
# revenueGrowth: 0.226
# earningsGrowth: 0.287
# pegRatio: 2.275513588850174
# enterpriseValue: 848052486144
# totalDebt: 4738719744
# totalRevenue: 113192337408
# freeCashflow: 1990682496
#
# Computed ROE: 24.13%
# Computed ROA: 14.83%
# Fundamental Score: 6.85/10
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5558.30
# 50-Day MA: 5699.01
# 200-Day MA: 5377.32
# RSI (14): 66.15
# MACD: -103.88
# MACD Signal: -158.53
# Bollinger Bands Score: 10.00
# ATR (14): 212.59
# Volume MA (20): 592388.50
# Rate of Change (12): 4.81%
#
# Technical Score: 8.71/10
#
# Composite Financial Strength Score: 7.59/10
# ============================================================
#
# === Indraprastha Gas Limited (IGL.NS) ===
# Fundamental Metrics:
# longName: Indraprastha Gas Limited
# sector: Utilities
# industry: Utilities - Regulated Gas
# marketCap: 279159996416
# trailingPE: 16.438581
# forwardPE: 6.83579
# dividendYield: 2.58
# dividendRate: 5.25
# fiftyTwoWeekHigh: 285.175
# fiftyTwoWeekLow: 153.05
# returnOnEquity: N/A
# returnOnAssets: 0.13959743909265568
# debtToEquity: 0.7
# profitMargins: 0.11655
# operatingMargins: 0.063930005
# grossMargins: 0.23948999
# ebitdaMargins: 0.13262999
# bookValue: 75.505
# priceToBook: 2.6408846
# revenueGrowth: 0.057
# earningsGrowth: -0.314
# pegRatio: N/A
# enterpriseValue: 248603623424
# totalDebt: 741800000
# totalRevenue: 145552900096
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 13.96%
# Fundamental Score: 7.60/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 199.40
# 50-Day MA: 194.00
# 200-Day MA: 223.47
# RSI (14): 71.01
# MACD: 1.18
# MACD Signal: -0.78
# Bollinger Bands Score: 10.00
# ATR (14): 6.54
# Volume MA (20): 4219040.10
# Rate of Change (12): 6.01%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 7.36/10
# ============================================================
#
# === Info Edge (India) Limited (NAUKRI.NS) ===
# Fundamental Metrics:
# longName: Info Edge (India) Limited
# sector: Communication Services
# industry: Internet Content & Information
# marketCap: 924489285632
# trailingPE: 164.95152
# forwardPE: 76.506424
# dividendYield: 0.34
# dividendRate: 24.0
# fiftyTwoWeekHigh: 9128.9
# fiftyTwoWeekLow: 5152.2
# returnOnEquity: N/A
# returnOnAssets: 0.015937794257685944
# debtToEquity: 0.59
# profitMargins: 0.20278
# operatingMargins: 0.3346
# grossMargins: 0.53223
# ebitdaMargins: 0.33094
# bookValue: 3234.003
# priceToBook: 2.2095528
# revenueGrowth: 0.152
# earningsGrowth: 0.599
# pegRatio: 2.7537816360601
# enterpriseValue: 897408237568
# totalDebt: 2556430080
# totalRevenue: 27573479424
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.59%
# Fundamental Score: 7.04/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 7145.70
# 50-Day MA: 7289.98
# 200-Day MA: 7541.39
# RSI (14): 61.63
# MACD: -137.68
# MACD Signal: -220.06
# ...
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.43/10
# ============================================================
#
# === Sona BLW Precision Forgings Limited (SONACOMS.NS) ===
# Fundamental Metrics:
# longName: Sona BLW Precision Forgings Limited
# sector: Consumer Cyclical
# industry: Auto Parts
# marketCap: 306942181376
# trailingPE: 50.429012
# forwardPE: 37.27222
# dividendYield: 0.64
# dividendRate: 3.2
# fiftyTwoWeekHigh: 768.65
# fiftyTwoWeekLow: 464.05
# returnOnEquity: N/A
# returnOnAssets: 0.13383664781070104
# debtToEquity: 3.744
# profitMargins: 0.16429001
# operatingMargins: 0.19313
# grossMargins: 0.54763
# ebitdaMargins: 0.26429
# bookValue: 87.934
# priceToBook: 5.6144385
# revenueGrowth: 0.11
# earningsGrowth: 0.075
# pegRatio: 6.723868266666667
# enterpriseValue: 281360728064
# totalDebt: 2015040000
# totalRevenue: 35653951488
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 13.38%
# Fundamental Score: 6.15/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 493.70
# 50-Day MA: 513.78
# 200-Day MA: 630.51
# RSI (14): 57.93
# MACD: -4.45
# MACD Signal: -5.71
# Bollinger Bands Score: 10.00
# ATR (14): 18.90
# Volume MA (20): 1391654.85
# Rate of Change (12): -5.40%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.66/10
# ============================================================
#
# === InterGlobe Aviation Limited (INDIGO.NS) ===
# Fundamental Metrics:
# longName: InterGlobe Aviation Limited
# sector: Industrials
# industry: Airlines
# marketCap: 1934704115712
# trailingPE: 31.776468
# forwardPE: 24.369434
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 5190.35
# fiftyTwoWeekLow: 3302.35
# returnOnEquity: N/A
# returnOnAssets: 0.09939210710109735
# debtToEquity: 1558.415
# profitMargins: 0.07958
# operatingMargins: 0.19943
# grossMargins: 0.32027
# ebitdaMargins: 0.13467
# bookValue: 98.427
# priceToBook: 50.86714
# revenueGrowth: 0.137
# earningsGrowth: -0.184
# pegRatio: N/A
# enterpriseValue: 2166403366912
# totalDebt: 592369025024
# totalRevenue: 764762390528
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 9.94%
# Fundamental Score: 5.74/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5006.70
# 50-Day MA: 4449.15
# 200-Day MA: 4438.26
# RSI (14): 71.09
# MACD: 159.32
# MACD Signal: 131.99
# Bollinger Bands Score: 10.00
# ATR (14): 119.30
# Volume MA (20): 983841.40
# Rate of Change (12): 5.13%
#
# Technical Score: 8.29/10
#
# Composite Financial Strength Score: 6.76/10
# ============================================================
#
# === Glenmark Pharmaceuticals Limited (GLENMARK.NS) ===
# Fundamental Metrics:
# longName: Glenmark Pharmaceuticals Limited
# sector: Healthcare
# industry: Drug Manufacturers - Specialty & Generic
# marketCap: 417975730176
# trailingPE: N/A
# forwardPE: 34.857582
# dividendYield: 0.17
# dividendRate: 2.5
# fiftyTwoWeekHigh: 1830.95
# fiftyTwoWeekLow: 936.0
# returnOnEquity: N/A
# returnOnAssets: -0.10458300182524453
# debtToEquity: 21.086
# profitMargins: -0.0125899995
# operatingMargins: 0.14095001
# grossMargins: 0.68301004
# ebitdaMargins: 0.21981001
# bookValue: 598.469
# priceToBook: 2.47423
# revenueGrowth: 0.351
# earningsGrowth: N/A
# pegRatio: N/A
# enterpriseValue: 420841652224
# totalDebt: 17808490496
# totalRevenue: 139607703552
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: -10.46%
# Fundamental Score: 6.95/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1480.75
# 50-Day MA: 1425.41
# 200-Day MA: 1515.68
# RSI (14): 76.83
# MACD: 21.89
# MACD Signal: 6.17
# Bollinger Bands Score: 10.00
# ATR (14): 36.86
# Volume MA (20): 518349.50
# Rate of Change (12): 6.02%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 6.97/10
# ============================================================
#
# === J.K. Cement Limited (JKCEMENT.NS) ===
# Fundamental Metrics:
# longName: J.K. Cement Limited
# sector: Basic Materials
# industry: Building Materials
# marketCap: 366966013952
# trailingPE: 50.853947
# forwardPE: 68.383736
# dividendYield: 0.32
# dividendRate: 15.0
# fiftyTwoWeekHigh: 4988.95
# fiftyTwoWeekLow: 3642.0
# returnOnEquity: N/A
# returnOnAssets: 0.05342687861857439
# debtToEquity: 104.504
# profitMargins: 0.06318
# operatingMargins: 0.118240006
# grossMargins: 0.61866003
# ebitdaMargins: 0.16266
# bookValue: 714.952
# priceToBook: 6.6427536
# revenueGrowth: -0.002
# earningsGrowth: -0.332
# pegRatio: N/A
# enterpriseValue: 418260811776
# totalDebt: 57380298752
# totalRevenue: 114037399552
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 5.34%
# Fundamental Score: 5.36/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4749.25
# 50-Day MA: 4625.65
# 200-Day MA: 4464.76
# RSI (14): 67.49
# MACD: 19.91
# MACD Signal: -32.74
# Bollinger Bands Score: 10.00
# ATR (14): 123.87
# Volume MA (20): 119831.80
# Rate of Change (12): 5.42%
#
# Technical Score: 8.71/10
#
# Composite Financial Strength Score: 6.70/10
# ============================================================
#
# === Trent Limited (TRENT.NS) ===
# Fundamental Metrics:
# longName: Trent Limited
# sector: Consumer Cyclical
# industry: Apparel Retail
# marketCap: 1843238535168
# trailingPE: 94.981674
# forwardPE: 76.11641
# dividendYield: 0.06
# dividendRate: 3.2
# fiftyTwoWeekHigh: 8345.0
# fiftyTwoWeekLow: 3843.0
# returnOnEquity: N/A
# returnOnAssets: 0.207602890355011
# debtToEquity: 39.033
# profitMargins: 0.1192
# operatingMargins: 0.12821001
# grossMargins: 0.42917
# ebitdaMargins: 0.124469995
# bookValue: 133.103
# priceToBook: 38.95517
# revenueGrowth: 0.343
# earningsGrowth: 0.329
# pegRatio: 2.886980972644377
# enterpriseValue: 1851855732736
# totalDebt: 18421999616
# totalRevenue: 162153693184
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 20.76%
# Fundamental Score: 6.59/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 5185.05
# 50-Day MA: 5360.23
# 200-Day MA: 6299.06
# RSI (14): 58.05
# MACD: -56.18
# MACD Signal: -106.65
# Bollinger Bands Score: 10.00
# ATR (14): 169.77
# Volume MA (20): 1114570.95
# Rate of Change (12): 2.28%
#
# Technical Score: 7.86/10
#
# Composite Financial Strength Score: 7.10/10
# ============================================================
#
# === L&T Technology Services Limited (LTTS.NS) ===
# Fundamental Metrics:
# longName: L&T Technology Services Limited
# sector: Technology
# industry: Information Technology Services
# marketCap: 489543008256
# trailingPE: 37.829624
# forwardPE: 31.307453
# dividendYield: 1.09
# dividendRate: 50.0
# fiftyTwoWeekHigh: 6000.0
# fiftyTwoWeekLow: 4200.0
# returnOnEquity: N/A
# returnOnAssets: 0.15358426105907994
# debtToEquity: 11.42
# profitMargins: 0.12681
# operatingMargins: 0.15903
# grossMargins: 0.46967
# ebitdaMargins: 0.17243
# bookValue: 531.014
# priceToBook: 8.709846
# revenueGrowth: 0.095
# earningsGrowth: -0.042
# pegRatio: N/A
# enterpriseValue: 469365882880
# totalDebt: 6441999872
# totalRevenue: 102253002752
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 15.36%
# Fundamental Score: 6.16/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4625.05
# 50-Day MA: 5000.04
# 200-Day MA: 5119.00
# RSI (14): 52.44
# MACD: -110.12
# MACD Signal: -134.84
# Bollinger Bands Score: 10.00
# ATR (14): 171.29
# Volume MA (20): 136458.75
# Rate of Change (12): -4.80%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.67/10
# ============================================================
#
# === Max Healthcare Institute Limited (MAXHEALTH.NS) ===
# Fundamental Metrics:
# longName: Max Healthcare Institute Limited
# sector: Healthcare
# industry: Medical Care Facilities
# marketCap: 1140179206144
# trailingPE: 113.63857
# forwardPE: 61.020756
# dividendYield: 0.13
# dividendRate: 1.5
# fiftyTwoWeekHigh: 1227.95
# fiftyTwoWeekLow: 737.5
# returnOnEquity: N/A
# returnOnAssets: 0.08813710735220343
# debtToEquity: 20.095
# profitMargins: 0.15415
# operatingMargins: 0.21495001
# grossMargins: 0.62341
# ebitdaMargins: 0.24925
# bookValue: 90.548
# priceToBook: 12.9516945
# revenueGrowth: 0.4
# earningsGrowth: -0.178
# pegRatio: N/A
# enterpriseValue: 1143244455936
# totalDebt: 17681899520
# totalRevenue: 65416200192
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 8.81%
# Fundamental Score: 6.08/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 1172.75
# 50-Day MA: 1048.38
# 200-Day MA: 993.38
# RSI (14): 76.52
# MACD: 26.55
# MACD Signal: 2.51
# Bollinger Bands Score: 4.00
# ATR (14): 39.56
# Volume MA (20): 2632582.85
# Rate of Change (12): 17.29%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.62/10
# ============================================================
#
# === Eternal Limited (ZOMATO.NS) ===
# Fundamental Metrics:
# longName: Eternal Limited
# sector: Consumer Cyclical
# industry: Internet Retail
# marketCap: 1901921435648
# trailingPE: 276.0658
# forwardPE: 83.257935
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 304.7
# fiftyTwoWeekLow: 146.3
# returnOnEquity: N/A
# returnOnAssets: 0.015028258263401267
# debtToEquity: 5.439
# profitMargins: 0.03689
# operatingMargins: -0.01573
# grossMargins: 0.60199
# ebitdaMargins: 0.01505
# bookValue: 24.442
# priceToBook: 8.583995
# revenueGrowth: 0.644
# earningsGrowth: -0.625
# pegRatio: N/A
# enterpriseValue: 1822623137792
# totalDebt: 11589999616
# totalRevenue: 179719995392
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.50%
# Fundamental Score: 4.96/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 209.81
# 50-Day MA: 222.95
# 200-Day MA: 245.71
# RSI (14): 37.28
# MACD: -2.77
# MACD Signal: -3.84
# Bollinger Bands Score: 10.00
# ATR (14): 9.53
# Volume MA (20): 58250730.35
# Rate of Change (12): -6.93%
#
# Technical Score: 7.00/10
#
# Composite Financial Strength Score: 5.77/10
# ============================================================
#
# === IndusInd Bank Limited (INDUSINDBK.NS) ===
# Fundamental Metrics:
# longName: IndusInd Bank Limited
# sector: Financial Services
# industry: Banks - Regional
# marketCap: 496296361984
# trailingPE: 6.8463187
# forwardPE: 6.596086
# dividendYield: 2.46
# dividendRate: 16.5
# fiftyTwoWeekHigh: 1576.35
# fiftyTwoWeekLow: 606.0
# returnOnEquity: N/A
# returnOnAssets: 0.017428454813456076
# debtToEquity: N/A
# profitMargins: 0.28699
# operatingMargins: 0.31801
# grossMargins: 0.0
# ebitdaMargins: 0.0
# bookValue: 843.423
# priceToBook: 0.75531495
# revenueGrowth: -0.131
# earningsGrowth: -0.391
# pegRatio: N/A
# enterpriseValue: 483018080256
# totalDebt: 447161204736
# totalRevenue: 252749086720
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 1.74%
# Fundamental Score: 7.43/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 637.05
# 50-Day MA: 935.01
# 200-Day MA: 1183.52
# RSI (14): 11.42
# MACD: -93.87
# MACD Signal: -78.20
# Bollinger Bands Score: 7.00
# ATR (14): 49.94
# Volume MA (20): 22032054.00
# Rate of Change (12): -34.44%
#
# Technical Score: 4.43/10
#
# Composite Financial Strength Score: 6.23/10
# ============================================================
#
# === BSE Limited (BSE.NS) ===
# Fundamental Metrics:
# longName: BSE Limited
# sector: Financial Services
# industry: Financial Data & Stock Exchanges
# marketCap: 629721726976
# trailingPE: 67.97676
# forwardPE: 51.223984
# dividendYield: 0.32
# dividendRate: 15.0
# fiftyTwoWeekHigh: 6133.4
# fiftyTwoWeekLow: 2115.0
# returnOnEquity: N/A
# returnOnAssets: 0.08236730746235806
# debtToEquity: 0.0
# profitMargins: 0.32810003
# operatingMargins: 0.67991996
# grossMargins: 0.99568003
# ebitdaMargins: 0.56479
# bookValue: 343.489
# priceToBook: 13.542355
# revenueGrowth: 0.952
# earningsGrowth: 1.03
# pegRatio: 0.6599685436893203
# enterpriseValue: 572879667200
# totalDebt: 200000
# totalRevenue: 28604499968
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 8.24%
# Fundamental Score: 7.48/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 4651.65
# 50-Day MA: 5117.85
# 200-Day MA: 4072.99
# RSI (14): 55.16
# MACD: -179.98
# MACD Signal: -276.07
# Bollinger Bands Score: 10.00
# ATR (14): 239.98
# Volume MA (20): 4867570.15
# Rate of Change (12): 9.36%
#
# Technical Score: 8.71/10
#
# Composite Financial Strength Score: 7.97/10
# ============================================================
#
# === Titan Company Limited (TITAN.NS) ===
# Fundamental Metrics:
# longName: Titan Company Limited
# sector: Consumer Cyclical
# industry: Luxury Goods
# marketCap: 2708769341440
# trailingPE: 84.0545
# forwardPE: 54.35564
# dividendYield: 0.36
# dividendRate: 11.0
# fiftyTwoWeekHigh: 3867.0
# fiftyTwoWeekLow: 2985.05
# returnOnEquity: N/A
# returnOnAssets: 0.11080824088748019
# debtToEquity: 222.35
# profitMargins: 0.05578
# operatingMargins: 0.0845
# grossMargins: 0.21246
# ebitdaMargins: 0.08558
# bookValue: 109.807
# priceToBook: 27.809702
# revenueGrowth: 0.252
# earningsGrowth: -0.008
# pegRatio: N/A
# enterpriseValue: 2893711671296
# totalDebt: 216480006144
# totalRevenue: 580340023296
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 11.08%
# Fundamental Score: 5.84/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 3053.70
# 50-Day MA: 3245.64
# 200-Day MA: 3384.51
# RSI (14): 50.48
# MACD: -44.65
# MACD Signal: -58.81
# Bollinger Bands Score: 10.00
# ATR (14): 62.27
# Volume MA (20): 857588.55
# Rate of Change (12): -2.16%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.48/10
# ============================================================
#
# === Vodafone Idea Limited (IDEA.NS) ===
# Fundamental Metrics:
# longName: Vodafone Idea Limited
# sector: Communication Services
# industry: Telecom Services
# marketCap: 510459969536
# trailingPE: N/A
# forwardPE: -1.9015958
# dividendYield: N/A
# dividendRate: N/A
# fiftyTwoWeekHigh: 19.18
# fiftyTwoWeekLow: 6.61
# returnOnEquity: N/A
# returnOnAssets: -0.16885831553581476
# debtToEquity: N/A
# profitMargins: -0.64744
# operatingMargins: -0.08407
# grossMargins: 0.43979
# ebitdaMargins: 0.27336
# bookValue: -13.693
# priceToBook: -0.52216464
# revenueGrowth: 0.04
# earningsGrowth: N/A
# pegRatio: N/A
# enterpriseValue: 2856872837120
# totalDebt: 2501666930688
# totalRevenue: 430800011264
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: -16.89%
# Fundamental Score: 6.35/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 7.15
# 50-Day MA: 8.33
# 200-Day MA: 11.03
# RSI (14): 45.36
# MACD: -0.28
# MACD Signal: -0.33
# Bollinger Bands Score: 10.00
# ATR (14): 0.37
# Volume MA (20): 398987484.25
# Rate of Change (12): -7.50%
#
# Technical Score: 7.43/10
#
# Composite Financial Strength Score: 6.78/10
# ============================================================
#
# === Jindal Stainless Limited (JSL.NS) ===
# Fundamental Metrics:
# longName: Jindal Stainless Limited
# sector: Basic Materials
# industry: Steel
# marketCap: 484303306752
# trailingPE: 20.052847
# forwardPE: 10.8334875
# dividendYield: 0.51
# dividendRate: 3.0
# fiftyTwoWeekHigh: 848.0
# fiftyTwoWeekLow: 568.05
# returnOnEquity: N/A
# returnOnAssets: 0.08804192457146566
# debtToEquity: 41.807
# profitMargins: 0.06262
# operatingMargins: 0.09749
# grossMargins: 0.30464
# ebitdaMargins: 0.115229994
# bookValue: 187.67
# priceToBook: 3.1339588
# revenueGrowth: 0.085
# earningsGrowth: -0.055
# pegRatio: N/A
# enterpriseValue: 528195944448
# totalDebt: 64730800128
# totalRevenue: 385679097856
# freeCashflow: N/A
#
# Computed ROE: N/A
# Computed ROA: 8.80%
# Fundamental Score: 6.16/10
#
# Additional info for missing metrics:
# Empty DataFrame
# Columns: [Attribute, Value]
# Index: []
#
#
# Technical Metrics as of 2025-03-25:
# Close Price: 588.15
# 50-Day MA: 622.05
# 200-Day MA: 706.24
# RSI (14): 48.37
# MACD: -1.42
# MACD Signal: 2.41
# Bollinger Bands Score: 10.00
# ATR (14): 25.29
# Volume MA (20): 1039681.15
# Rate of Change (12): -9.78%
#
# Technical Score: 6.57/10
#
# Composite Financial Strength Score: 6.32/10
# ============================================================
#
# Results saved to composite_scores2_finallllll.xlsx
